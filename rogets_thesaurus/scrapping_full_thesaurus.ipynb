# %% [markdown]
# # Roget's Thesaurus in the 21st Century
# ---
# >Spanakis Panagiotis-Alexios, Pregraduate Student
# Department of Management Science and Technology
# Athens University of Economics and Business
# t8200158@aueb.gr

# %% [markdown]
# ## Before we start
#
# We first need to go over the dependencies needed for this notebook to function properly

# %% [markdown]
# ### Dependencies for all the Notebooks in the Project
#
#
# We will need to use libraries that are not included in the Python Standard Library which are handled using Poetry
#
# In order to install the dependencies, we will need to run the following commands in the terminal
#
# 1. (If we haven't already installed Poetry)
# ```bash
# pip install poetry
# ```
#
# 2. After we have installed Poetry, we will need to run the following command in the terminal
# ```bash
# poetry install
# ```
#
# 3. (Optional) If we want to use the Jupyter Notebook with the virtual environment created by Poetry, we will need to run the following command in the terminal
# ```bash
# poetry shell
# ```
#
# 4. After we have installed the dependencies, we will need to run the following command in the terminal
# ```bash
# jupyter notebook
# ```

# %% [markdown]
# We will use the following libraries:
#
# - `pandas` for data manipulation
# ---
# - `requests` for making HTTP requests
# - `beautifulsoup4` for web scraping
# ---
# - `re` for regular expressions
# - `os` for file manipulation
# - `json` for JSON manipulation
# ---
# - `chromadb` to store the embeddings to a vector database
# - `nomic` in order to interact with the nomic API

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import re
import os
import json
import chromadb
from nomic import embed

# %% [markdown]
# ## Get Roget's Thesaurus Classification

# %% [markdown]
# ### Let's explain how the words along with their classes and divisions and sections are organized in the Gutenberg page
#
# The words are organized in the page in the following manner:
#
# 1) They belong to a class
# 2) They belong to a division (if it exists) within the class
# 3) They belong to a section within the division (if it exists) or within the class
#
# Let's start by getting the page and parsing it

# %%
# Get the page
r = requests.get("https://www.gutenberg.org/files/10681/old/20040627-10681-h-body-pos.htm")
# Parse the page
html = r.text
# Create a BeautifulSoup object
soup = BeautifulSoup(html, 'html.parser')

# %% [markdown]
# 1) We can notice that all classes on the page are represented by a `<dt>` tag with an `<a>` tag inside it.
# The `<a>` tag has a name attribute that starts with **`CLASS`**. The text of the `<a>` tag is the name of the class.
#
#
# 2) We can notice that all divisions on the page are represented by a `<dt>` tag with an `<a>` tag inside it.
# The `<a>` tag has a name attribute that starts with **`DIVISION`**. The text of the `<a>` tag is the name of the division.
#
#
# 3) We can notice that all sections on the page are represented by a `<dt>` tag with an `<a>` tag inside it.
# The `<a>` tag has a name attribute that starts with **`SECTION`**. The text of the `<a>` tag is the name of the section.
#
# Lastly, the words are represented by a `<dt>` tag with an `<a>` tag inside it. The `<a>` tag has a name attribute that is a number or a number with a letter at the end.
# We notice that the words come after the `<a>` tag where the name attribute is a number and also that tag is inside a `<b>` tag.
# So in order to get the words we must get the text of the `<b>` tag that comes after the `<a>` tag where the name attribute is a number.

# %% [markdown]
# With the above in mind, we can extract the hierarchy of classes, divisions, sections, and words from the page.
# We can then create a directory structure that mirrors the structure of the page and save the words under each section to a file in the directory structure
# using a dictionary to hold the entire hierarchy.

# %%
# Initialize a dictionary to hold the entire hierarchy
hierarchy = {}
current_class = None
current_division = None
current_section = None

# Find all <dt> tags
dt_tags = soup.find_all('dt')

# %% [markdown]
# Having the dictionary initialized and the `<dt>` tags found, we can now iterate through each `<dt>` tag and extract the hierarchy of classes, divisions, sections, and words from the page. Also, split the words if they have a comma or a dot and add them to the hierarchy separately.
#
# We will use the following logic to extract the hierarchy:
#
# 1) If the `<dt>` tag has an `<a>` tag with a name attribute that starts with **`CLASS`** then we have found a class. We will add the class to the hierarchy and continue to the next `<dt>` tag to check for division/section.
# 2) If the `<dt>` tag has an `<a>` tag with a name attribute that starts with **`DIVISION`** then we have found a division. We will add the division to the hierarchy and continue to the next `<dt>` tag to check for section.
# 3) If the `<dt>` tag has an `<a>` tag with a name attribute that starts with **`SECTION`** then we have found a section. We will add the section to the hierarchy and continue to the next `<dt>` tag to check for words.
# 4) Lastly, if the we have found a section, then we have found words. We will add the words to the hierarchy under the section.
# 5) We will also exclude common stop words such as "adj", "plur", "adv", "lat", "v", "n", "c", "i", "no", "and", "phr" from the words and convert them to lowercase,
# and remove any duplicates.

# %%
# Define a set of common stop words to exclude
stop_words = {"adj", "plur", "adv", "lat", "v", "n", "c", "i", "no", "and", "phr"}

for dt in dt_tags:
    class_a_tag = dt.find('a', attrs={'name': re.compile("^CLASS")})
    if class_a_tag:
        current_class = re.sub(r'\s+', ' ', class_a_tag.text).strip()
        hierarchy[current_class] = {'divisions': {}, 'sections': {}}
        current_division = None
        current_section = None
        continue

    division_a_tag = dt.find('a', attrs={'name': re.compile("^DIVISION")})
    if division_a_tag and current_class:
        current_division = re.sub(r'\s+', ' ', division_a_tag.text).strip()
        hierarchy[current_class]['divisions'][current_division] = {'sections': {}}
        current_section = None
        continue

    section_a_tag = dt.find('a', attrs={'name': re.compile("^SECTION")})
    if section_a_tag:
        current_section = re.sub(r'\s+', ' ', section_a_tag.text).strip()
        if current_division:
            hierarchy[current_class]['divisions'][current_division]['sections'][current_section] = []
        else:
            hierarchy[current_class]['sections'][current_section] = []
        continue

    if current_section:
        text = dt.get_text(separator=' ', strip=True)
        text = re.sub(r'\[.*?\]', '', text)
        words = re.findall(r'\b[a-zA-Z]{2,}\b', text)
        filtered_words = set(word.lower() for word in words if word.lower() not in stop_words)
        
        if current_division:
            hierarchy[current_class]['divisions'][current_division]['sections'][current_section].extend(list(filtered_words))
            hierarchy[current_class]['divisions'][current_division]['sections'][current_section] = list(set(hierarchy[current_class]['divisions'][current_division]['sections'][current_section]))
        else:
            hierarchy[current_class]['sections'][current_section].extend(list(filtered_words))
            hierarchy[current_class]['sections'][current_section] = list(set(hierarchy[current_class]['sections'][current_section]))

for class_key, class_value in hierarchy.items():
    for section_key in class_value['sections']:
        class_value['sections'][section_key] = list(set(class_value['sections'][section_key]))
    for division_key, division_value in class_value['divisions'].items():
        for section_key in division_value['sections']:
            division_value['sections'][section_key] = list(set(division_value['sections'][section_key]))

print(hierarchy)
# Out:
# {'WORDS EXPRESSING ABSTRACT RELATIONS': {'divisions': {}, 'sections': {'EXISTENCE': ['earth', 'abeyance', 'object', 'principle', 'inhesion', 'mold', 'substantiality', 'nirvana', 'creature', 'features', 'environment', 'emergence', 'of', 'peculiarities', 'nullity', 'moods', 'declensions', 'tone', 'footing', 'point', 'oddity', 'space', 'objectiveness', 'faggot', 'status', 'formal', 'abstract', 'one', 'speciality', 'core', 'disposition', 'lot', 'ontology', 'nothing', 'nihil', 'fool', 'pith', 'tabula', 'reality', 'nihility', 'absence', 'nil', 'imagination', 'air', 'esse', 'talk', 'crasis', 'are', 'form', 'uncertainty', 'actuality', 'ii', 'in', 'thing', 'oblivion', 'john', 'inmost', 'nature', 'inanity', 'marrow', 'fabric', 'non', 'annihilation', 'appearance', 'juncture', 'power', 'circumstance', 'turn', 'ignis', 'humor', 'diathesis', 'nominis', 'endowment', 'being', 'zero', 'nonsubsistence', 'destruction', 'insubstantiality', 'tenor', 'posture', 'body', 'void', 'mood', 'sober', 'pass', 'event', 'whatever', 'er', 'attitude', 'capacity', 'location', 'habit', 'intrinsicality', 'exigency', 'diagnostics', 'at', 'pinch', 'matter', 'nonsense', 'positiveness', 'umbra', 'thin', 'hollowness', 'inherence', 'an', 'heart', 'pickle', 'essential', 'occurrence', 'moonshine', 'stubborn', 'concrete', 'entity', 'fact', 'egohood', 'coexistence', 'blood', 'temperament', 'estate', 'set', 'dreams', 'extraneousness', 'voter', 'land', 'mode', 'truth', 'soul', 'part', 'bubble', 'phr', 'constitution', 'baseless', 'type', 'nonentity', 'such', 'none', 'fatuus', 'actual', 'tendency', 'plenum', 'conjunctive', 'trim', 'modality', 'person', 'joke', 'existence', 'situation', 'push', 'temper', 'never', 'doe', 'turning', 'straw', 'subjectiveness', 'element', 'negativeness', 'mould', 'schesis', 'capability', 'dream', 'sap', 'stamp', 'contingency', 'place', 'ego', 'aspects', 'on', 'lifeblood', 'style', 'smallness', 'complexion', 'substance', 'character', 'ease', 'inexistence', 'causation', 'category', 'nihilism', 'quiddity', 'light', 'emergency', 'subsistence', 'presence', 'substantialness', 'luminary', 'nobody', 'idiocrasy', 'naught', 'state', 'fashion', 'life', 'paradise', 'surroundings', 'occasion', 'bearings', 'not', 'vital', 'corporeity', 'particle', 'aspect', 'how', 'standing', 'essentialness', 'vision', 'important', 'blank', 'extirpation', 'richard', 'extinction', 'backbone', 'as', 'dilemma', 'idiosyncrasy', 'modal', 'the', 'plight', 'item', 'extinguishment', 'consequence', 'degree', 'fit', 'crisis', 'extrinsicality', 'phantom', 'hypostasis', 'attribution', 'regime', 'quantity', 'position', 'guise', 'shadow', 'roe', 'mockery', 'hard', 'vapor', 'materiality', 'frame', 'accident', 'article', 'obliteration', 'substratum', 'unsubstantiality', 'spirit', 'rasa', 'phase', 'essence', 'inner', 'flesh', 'quintessence', 'phenomenon', 'nonexistence', 'made', 'quality', 'world', 'terms', 'section', 'flash', 'et', 'pan', 'cipher', 'nonbeing', 'predicament', 'groundwork', 'stuff', 'something', 'importance', 'praeterea', 'lies', 'gist', 'ens', 'fallacy', 'condition', 'man', 'dependence', 'incarnation', 'habitude', 'all', 'vox', 'grain', 'shape', 'context', 'noumenon', 'ne', 'nothingness', 'inbeing', 'center'], 'RELATION': ['discrimination', 'mold', 'tracing', 'independence', 'celluloid', 'moods', 'uniformness', 'exemplar', 'tree', 'likeness', 'similitude', 'variance', 'nihil', 'faithful', 'discordance', 'or', 'de', 'extreme', 'offprint', 'accommodation', 'union', 'distinction', 'inconnection', 'constancy', 'association', 'harmony', 'concordia', 'color', 'duplication', 'mimicry', 'general', 'negative', 'gens', 'irregularity', 'meme', 'contrariety', 'inversion', 'converse', 'admissibility', 'proportion', 'same', 'opposition', 'repugnance', 'blood', 'counterfeit', 'parity', 'consistency', 'interdependence', 'apograph', 'archetype', 'lay', 'antagonism', 'coaptation', 'agreement', 'roughness', 'pattern', 'keynote', 'parrot', 'seal', 'even', 'diversity', 'equality', 'deviation', 'trav ...

# %% [markdown]
# Now that we have the hierarchy of classes, divisions, sections, and words, we can take at the hierarchy we created.

# %%
hierarchy['WORDS EXPRESSING ABSTRACT RELATIONS']
# Out:
# {'divisions': {},
#  'sections': {'EXISTENCE': ['earth',
#    'abeyance',
#    'object',
#    'principle',
#    'inhesion',
#    'mold',
#    'substantiality',
#    'nirvana',
#    'creature',
#    'features',
#    'environment',
#    'emergence',
#    'of',
#    'peculiarities',
#    'nullity',
#    'moods',
#    'declensions',
#    'tone',
#    'footing',
#    'point',
#    'oddity',
#    'space',
#    'objectiveness',
#    'faggot',
#    'status',
#    'formal',
#    'abstract',
#    'one',
#    'speciality',
#    'core',
#    'disposition',
#    'lot',
#    'ontology',
#    'nothing',
#    'nihil',
#    'fool',
#    'pith',
#    'tabula',
#    'reality',
#    'nihility',
#    'absence',
#    'nil',
#    'imagination',
#    'air',
#    'esse',
#    'talk',
#    'crasis',
#    'are',
#    'form',
#    'uncertainty',
#    'actuality',
#    'ii',
#    'in',
#    'thing',
#    'oblivion',
#    'john',
#    'inmost',
#    'nature',
#    'inanity',
#    'marrow',
#    'fabric',
#    'non',
#    'annihilation',
#    'appearance',
#    'juncture',
#    'power',
#    'circumstance',
#    'turn',
#    'ignis',
#    'humor',
#    'diathesis',
#    'nominis',
#    'endowment',
#    'being',
#    'zero',
#    'nonsubsistence',
#    'destruction',
#    'insubstantiality',
#    'tenor',
#    'posture',
#    'body',
#    'void',
#    'mood',
#    'sober',
#    'pass',
#    'event',
#    'whatever',
#    'er',
#    'attitude',
#    'capacity',
#    'location',
#    'habit',
#    'intrinsicality',
#    'exigency',
#    'diagnostics',
#    'at',
#    'pinch',
#    'matter',
#    'nonsense',
#    'positiveness',
#    'umbra',
#    'thin',
#    'hollowness',
#    'inherence',
#    'an',
#    'heart',
#    'pickle',
#    'essential',
#    'occurrence',
#    'moonshine',
#    'stubborn',
#    'concrete',
#    'entity',
#    'fact',
#    'egohood',
#    'coexistence',
#    'blood',
#    'temperament',
#    'estate',
#    'set',
#    'dreams',
#    'extraneousness',
#    'voter',
#    'land',
#    'mode',
#    'truth',
#    'soul',
#    'part',
#    'bubble',
#    'phr',
#    'constitution',
#    'baseless',
#    'type',
#    'nonentity',
#    'such',
#    'none',
#    'fatuus',
#    'actual',
#    'tendency',
#    'plenum',
#    'conjunctive',
#    'trim',
#    'modality',
#    'person',
#    'joke',
#    'existence',
#    'situation',
#    'push',
#    'temper',
#    'never',
#    'doe',
#    'turning',
#    'straw',
#    'subjectiveness',
#    'element',
#    'negativeness',
#    'mould',
#    'schesis',
#    'capability',
#    'dream',
#    'sap',
#    'stamp',
#    'contingency',
#    'place',
#    'ego',
#    'aspects',
#    'on',
#    'lifeblood',
#    'style',
#    'smallness',
#    'complexion',
#    'substance',
#    'character',
#    'ease',
#    'inexistence',
#    'causation',
#    'category',
#    'nihilism',
#    'quiddity',
#    'light',
#    'emergency',
#    'subsistence',
#    'presence',
#    'substantialness',
#    'luminary',
#    'nobody',
#    'idiocrasy',
#    'naught',
#    'state',
#    'fashion',
#    'life',
#    'paradise',
#    'surroundings',
#    'occasion',
#    'bearings',
#    'not',
#    'vital',
#    'corporeity',
#    'particle',
#    'aspect',
#    'how',
#    'standing',
#    'essentialness',
#    'vision',
#    'important',
#    'blank',
#    'extirpation',
#    'richard',
#    'extinction',
#    'backbone',
#    'as',
#    'dilemma',
#    'idiosyncrasy',
#    'modal',
#    'the',
#    'plight',
#    'item',
#    'extinguishment',
#    'consequence',
#    'degree',
#    'fit',
#    'crisis',
#    'extrinsicality',
#    'phantom',
#    'hypostasis',
#    'attribution',
#    'regime',
#    'quantity',
#    'position',
#    'guise',
#    'shadow',
#    'roe',
#    'mockery',
#    'hard',
#    'vapor',
#    'materiality',
#    'frame',
#    'accident',
#    'article',
#    'obliteration',
#    'substratum',
#    'unsubstantiality',
#    'spirit',
#    'rasa',
#    'phase',
#    'essence',
#    'inner',
#    'flesh',
#    'quintessence',
#    'phenomenon',
#    'nonexistence',
#    'made',
#    'quality',
#    'world',
#    'terms',
#    'section',
#    'flash',
#    'et',
#    'pan',
#    'cipher',
#    'nonbeing',
#    'predicament',
#    'groundwork',
#    'stuff',
#    'something',
#    'importance',
#    'praeterea',
#    'lies',
#    'gist',
#    'ens',
#    'fallacy',
#    'condition',
#    'man',
#    'dependence',
#    'incarnation',
#    'habitude',
#    'all',
#    'vox',
#    'grain',
#    'shape',
#    'context',
#    'noumenon',
#    'ne',
#    'nothingness',
#    'inbeing',
#    'center'],
#   'RELATION': ['discrimination',
#    'mold',
#    'tracing',
#    'independence',
#    'celluloid',
#    'moods',
#    'uniformness',
#    'exemplar',
#    'tree',
#    'likeness',
#    'similitude',
#    'variance',
#    'nihil',
#    'faithful',
#    'discordance',
#    'or',
#    'de',
#    'extreme',
#    'offprint',
#    'accommodation',
#    'union',
#    'distinction',
#    'inconnection',
#    'constancy',
#    'association',
#    'harmony',
#    'concordia',
#    'color',
#    'duplication',
#    'mimicry',
#    'general',
#    'negative',
#    'gens',
#    'irregularity',
#    'meme',
#    'contrariety',
#    'inversion',
#    'converse',
#    'admissibility',
#    'proportion',
#    'same',
#    'opposition',
#    'repugnance',
#    'blood',
#    'counterfeit',
#    'parity',
#    'consistency',
#    'interdependence',
#    'apograph',
#    'archetype',
#    'lay',
#    'antagonism',
#    'coaptation',
#    'agreement',
#    'roughness',
#    'pattern',
#    'keynote',
#    'parrot',
#    'seal',
#    'even',
#    'diversity',
#    'equality',
#    'deviation',
#    'travestie',
#    'last',
#    'misjoinder',
#    'disjunction',
#    'analogy',
#    'only',
#    'design',
#    'uniformity',
#    'original',
#    'jarring',
#    'german',
#    'close',
#    'copying',
#    'discrepancy',
#    'expansion',
#    'sister',
#    'once',
#    'affinity',
#    'disproportion',
#    'commensurability',
#    'parallelism',
#    'fellow',
#    'inequality',
#    'antipodes',
#    'bickering',
#    'consentaneousness',
#    'reverse',
#    'irrelation',
#    'shadow',
#    'unison',
#    'plagiarist',
#    'case',
#    'contrast',
#    'near',
#    'connaturalness',
#    'congeniality',
#    'interest',
#    'unevenness',
#    'incongruence',
#    'disparity',
#    'arcades',
#    'variety',
#    'study',
#    'generation',
#    'photograph',
#    'sib',
#    'intrusion',
#    'very',
#    'feather',
#    'genus',
#    'quotation',
#    'this',
#    'block',
#    'adaption',
#    'of',
#    'point',
#    'dissimilitude',
#    'graduation',
#    'modification',
#    'nonuniformity',
#    'scantling',
#    'deception',
#    'dissociation',
#    'reflex',
#    'heterogeneity',
#    'in',
#    'pertinence',
#    'paraphrase',
#    'interrelation',
#    'reproduction',
#    'contradistinction',
#    'that',
#    'cast',
#    'shade',
#    'relationship',
#    'dissension',
#    'identity',
#    'reflexion',
#    'just',
#    'pertinencey',
#    'accord',
#    'tribe',
#    'homology',
#    'xerox',
#    'exactness',
#    'monkey',
#    'kinfolk',
#    'other',
#    'agnation',
#    'model',
#    'approximation',
#    'similar',
#    'phr',
#    'companion',
#    'sortance',
#    'cousin',
#    'actual',
#    'pendant',
#    'next',
#    'inconsequence',
#    'dissimilarity',
#    'continuous',
#    'falsehood',
#    'copyist',
#    'exchange',
#    'absolute',
#    'out',
#    'match',
#    'homoousia',
#    'else',
#    'family',
#    'adumbration',
#    'nuance',
#    'coincidence',
#    'own',
#    'servile',
#    'dissonance',
#    'aptitude',
#    'kindred',
#    'brother',
#    'stirps',
#    'edition',
#    'caricature',
#    'water',
#    'race',
#    'intaglio',
#    'reciprocator',
#    'reconcilement',
#    'subtle',
#    'relevancy',
#    'proplasm',
#    'understanding',
#    'differentia',
#    'strain',
#    'interchange',
#    'mime',
#    'wrangle',
#    'ad',
#    'image',
#    'example',
#    'inconcinnity',
#    'ectype',
#    'difference',
#    'mockery',
#    'disconnection',
#    'hoc',
#    'like',
#    'ambo',
#    'simile',
#    'copy',
#    'duplicate',
#    'dissidence',
#    'fish',
#    'dissemblance',
#    'flesh',
#    'consent',
#    'take',
#    'et',
#    'twin',
#    'omne',
#    'speaking',
#    'keeping',
#    'birds',
#    'pirate',
#    'similarity',
#    'ape',
#    'applicability',
#    'mccoy',
#    'fraternity',
#    'relative',
#    'lampoon',
#    'transcription',
#    'concern',
#    'counterpart',
#    'metaphor',
#    'incommensurability',
#    'apple',
#    'famille',
#    'tie',
#    'second',
#    'twice',
#    'aunt',
#    'travesty',
#    'imitation',
#    'bond',
#    'cognation',
#    'scan',
#    'creation',
#    'partial',
#    'quite',
#    'reciprocity',
#    'extension',
#    'discord',
#    'aberration',
#    'convertibility',
#    'fine',
#    'paternity',
#    'analogue',
#    'prototype',
#    'ties',
#    'figure',
#    'novelty',
#    'tenor',
#    'imitator',
#    'analogicalness',
#    'niece',
#    'sept',
#    'impertinence',
#    'derivation',
#    'concert',
#    'kinsman',
#    'module',
#    'effigies',
#    'oogamy',
#    'nice',
#    'bearing',
#    'kin',
#    'inverse',
#    'propriety',
#    'breed',
#    'oneself',
#    'fitness',
#    'clan',
#    'portrait',
#    'affiliation',
#    'rechauffe',
#    'ideal',
#    'alteration',
#    'protoplast',
#    'reduplication',
#    'mesalliance',
#    'tautology',
#    'coalescence',
#    'horse',
#    'mutual',
#    'verba',
#    'stamp',
#    'congruence',
#    'personation',
#    'ego',
#    'resemblance',
#    'echo',
#    'uncle',
#    'correlation',
#    'syncretism',
#    'transcript',
#    'isogamy',
#    'brotherhood',
#    'unfitness',
#    'dependency',
#    'inaptitude',
#    'simulation',
#    'assent',
#    'derivative',
#    'repetition',
#    'foil',
#    'reflection',
#    'shoes',
#    'dissimilaritude',
#    'ipsissima',
#    'punch',
#    'rem',
#    'off',
#    'double',
#    'matrix',
#    'irrelevancy',
#    'stock',
#    'plagiarism',
#    'revision',
#    'fugleman',
#    'conformance',
#    'inconsistency',
#    'position',
#    'relation',
#    'reprint',
#    'consonance',
#    'conformity',
#    'consanguinity',
#    'interference',
#    'nepotism',
#    'multifariousness',
#    'distant',
#    'misunderstanding',
#    'routine',
#    'unconformity',
#    'sibling',
#    'divarication',
#    'parentage',
#    'correspondence',
#    'pair',
#    'section',
#    'barter',
#    'opposite',
#    'cooperation',
#    'antithesis',
#    'plasm',
#    'alter',
#    'homogeneity',
#    'mocking',
#    'concurrence',
#    'man',
#    'homoiousia',
#    'forgery',
#    'parody',
#    'discors',
#    'representation',
#    'misrelation',
#    'pun',
#    'accordance',
#    'disagreement',
#    'bird',
#    'another',
#    'divergency',
#    'regularity',
#    'connection',
#    'unlikeness',
#    'one',
#    'nephew',
#    'nonimitation',
#    'incongruity',
#    'mutuality',
#    'contradiction',
#    'reference',
#    'burlesque',
#    'text',
#    'permutation',
#    'nobile',
#    'form',
#    'oppositeness',
#    'thing',
#    'chip',
#    'non',
#    'clashing',
#    'antitype',
#    'homogeneousness',
#    'creativeness',
#    'ratio',
#    'copycat',
#    'precedent',
#    'sisterhood',
#    'photo',
#    'mate',
#    'paradigm',
#    'fratrum',
#    'adjustment',
#    'right',
#    'reciprocation',
#    'invention',
#    'disproportionateness',
#    'offset',
#    'picture',
#    'irreconcilableness',
#    'identification',
#    'conflict',
#    'selfness',
#    'innovation',
#    'removed',
#    'die',
#    'discongruity',
#    'pasticcio',
#    'multiformity',
#    'concord',
#    'originality',
#    'ensample',
#    'standard',
#    'discrepance',
#    'parallel',
#    'type',
#    'mint',
#    'rhyme',
#    'real',
#    'electrotype',
#    'nation',
#    'old',
#    'congruity',
#    'reconciliation',
#    'facsimile',
#    'place',
#    'impersonation',
#    'iii',
#    'printing',
#    'alliteration',
#    'tenses',
#    'delicate',
#    'divergence',
#    'aptness',
#    'new',
#    'compatibility',
#    'fair',
#    'filiation',
#    'nearness',
#    'impropriety',
#    'self',
#    'assimilation',
#    'semblance',
#    'effigy',
#    'mimeograph',
#    'monotony',
#    'protoplasm',
#    'the',
#    'alliance',
#    'misjoining',
#    'lineage',
#    'cuckoo',
#    'link',
#    'inapplicability',
#    'change',
#    'side',
#    'kith',
#    'fake',
#    'different',
#    'apposition',
#    'sameness',
#    'first',
#    'something',
#    'connaturality',
#    'recording',
#    'variation',
#    'mismatch',
#    'comparison',
#    'cousinhood',
#    'concordance',
#    'striking',
#    'par',
#    'reciprocalness',
#    'reprocitist'],
#   'QUANTITY': ['discerption',
#    'creole',
#    'gleam',
#    'clause',
#    'remora',
#    'elision',
#    'prohibition',
#    'insignificance',
#    'extent',
#    'sejunction',
#    'centralization',
#    'hank',
#    'partiality',
#    'verse',
#    'spark',
#    'alien',
#    'subduction',
#    'compass',
#    'long',
#    'nothing',
#    'loss',
#    'astriction',
#    'gross',
#    'leaven',
#    'hasp',
#    'inkle',
#    'tittle',
#    'comparative',
#    'limb',
#    'bough',
#    'stepping',
#    'diffusion',
#    'dregs',
#    'screw',
#    'abridgment',
#    'greaser',
#    'intermedium',
#    'suspenders',
#    'useless',
#    'transcendence',
#    'gusset',
#    'excision',
#    'juncture',
#    'mulatto',
#    'personal',
#    'power',
#    'toughness',
#    'slice',
#    'union',
#    'indemnification',
#    'component',
#    'distinction',
#    'complexus',
#    'appurtenance',
#    'amends',
#    'redundancy',
#    'inconnection',
#    'support',
#    'reception',
#    'girth',
#    'tide',
#    'interposition',
#    'product',
#    'pro',
#    'detruncation',
#    'cortege',
#    'synthesis',
#    'length',
#    'aggrandizement',
#    'remnant',
#    'primus',
#    'shive',
#    'omission',
#    'amplitude',
#    'pitch',
#    'neutrality',
#    'holdfast',
#    'cestus',
#    'cement',
#    'shortening',
#    'intensity',
#    'general',
#    'share',
#    'dilatation',
#    'equal',
#    'immensity',
#    'chowchow',
#    'separatist',
#    'remanent',
#    'snick',
#    'concretion',
#    'button',
#    'preponderation',
#    'equivalent',
#    'gobbet',
#    'draw',
#    'surplus',
#    'cutting',
#    'disunion',
#    'chain',
#    'larigo',
#    'unimportant',
#    'corollary',
#    'potpourri',
#    'olla',
#    'counterpoise',
#    'candle',
#    'quinteron',
#    'intercourse',
#    'blood',
#    'shackle',
#    'mess',
#    'stone',
#    'parity',
#    'minority',
#    'set',
#    'noah',
#    'bushel',
#    'sand',
#    'embodiment',
#    'painter',
#    'trace',
#    'alloy',
#    'parting',
#    'iota',
#    'tendon',
#    'purification',
#    'resultant',
#    'elimination',
#    'preeminence',
#    'brace',
#    'part',
#    'aggregation',
#    'rate',
#    'fag',
#    'seclusion',
#    'hint',
#    'matrimony',
#    'amount',
#    'conjunctive',
#    'superfluity',
#    'eduction',
#    'fustie',
#    'changes',
#    'fill',
#    'equality',
#    'incoherence',
#    'ground',
#    'rip',
#    'stake',
#    'disjunction',
#    'minnows',
#    'eurasian',
#    'volume',
#    'integral',
#    'to',
#    'indemnity',
#    'post',
#    'incompleteness',
#    'love',
#    'limit',
#    'neck',
#    'peer',
#    'odds',
#    'trunk',
#    'lobule',
#    'sorts',
#    'category',
#    'quadroon',
#    'counteraction',
#    'whole',
#    'lion',
#    'trennel',
#    'supremacy',
#    'counterclaim',
#    'way',
#    'any',
#    'shortcoming',
#    'state',
#    'alloyage',
#    'ratchet',
#    'secundus',
#    'stranger',
#    'mick',
#    'nonadhesion',
#    'battle',
#    'lariat',
#    'expansion',
#    'diduction',
#    'string',
#    'spring',
#    'alienage',
#    'wagonload',
#    'catch',
#    'captain',
#    'harness',
#    'chapter',
#    'buzzsaw',
#    'unification',
#    'atom',
#    'cargo',
#    'half',
#    'adjunct',
#    'corruption',
#    'fellow',
#    'exteriority',
#    'inequality',
#    'yaffle',
#    'cord',
#    'aggravation',
#    'look',
#    'ablation',
#    'nullification',
#    'mestee',
#    'rank',
#    'additum',
#    'bellyful',
#    'admixture',
#    'terret',
#    'tatter',
#    'dissolution',
#    'cataclasm',
#    'hull',
#    'shadow',
#    'confluence',
#    'mite',
#    'separateness',
#    'gallimaufry',
#    'corking',
#    'scale',
#    'game',
#    'development',
#    'purity',
#    'co',
#    'scion',
#    'soupcon',
#    'growth',
#    'exception',
#    'major',
#    'strength',
#    'tooth',
#    'rise',
#    'yoke',
#    'bolt',
#    'hawser',
#    'mingled',
#    'world',
#    'mutilation',
#    'fullness',
#    'heat',
#    'casting',
#    'curtailment',
#    'residuum',
#    'scrag',
#    'pawl',
#    'thimbleful',
#    'tag',
#    'subsidence',
#    'ingredient',
#    'capful',
#    'disengagement',
#    'unevenness',
#    'withe',
#    'disparity',
#    'disunity',
#    'equipollence',
#    'scope',
#    'compagination',
#    'traces',
#    'aught',
#    'majority',
#    'patchwork',
#    'inseparability',
#    'stage',
#    'subtraction',
#    'exaggeration',
#    'dirt',
#    'discount',
#    'sex',
#    'vantage',
#    'shortage',
#    'abstractedness',
#    'dislocation',
#    'oasis',
#    'conjugation',
#    'mongrel',
#    'legadero',
#    'amalgamation',
#    'sliver',
#    'conglutination',
#    'subtrahend',
#    'smack',
#    'simple',
#    'lute',
#    'concatenation',
#    'adjection',
#    'of',
#    'station',
#    'reaction',
#    'point',
#    'sequel',
#    'hyphen',
#    'slit',
#    'ligature',
#    'generality',
#    'frustum',
#    'accession',
#    'ebb',
#    'deduction',
#    'commixtion',
#    'deterioration',
#    'lot',
#    'addition',
#    'making',
#    'droplet',
#    'idea',
#    'rent',
#    'hair',
#    'ascent',
#    'integrity',
#    'halter',
#    'line',
#    'multitude',
#    'articulation',
#    'scantling',
#    'counterbalance',
#    'symmetry',
#    'spoonful',
#    'in',
#    'detachment',
#    'disorder',
#    'region',
#    'resolution',
#    'sarmentum',
#    'rider',
#    'money',
#    'oxreim',
#    'sifting',
#    'stickiness',
#    'rejection',
#    'dab',
#    'amputation',
#    'seasoning',
#    'laceration',
#    'garnish',
#    'expulsion',
#    'short',
#    'adulteration',
#    'seam',
#    'connective',
#    'surcingle',
#    'size',
#    'sort',
#    'compensation',
#    'cast',
#    'analysis',
#    'segment',
#    'isthmus',
#    'shade',
#    'dissection',
#    'identity',
#    'imparity',
#    'chipping',
#    'suffix',
#    'podrida',
#    'inequation',
#    'cementation',
#    'just',
#    'shiver',
#    'mediocrity',
#    'missing',
#    'golden',
#    'complex',
#    'heap',
#    'preponderance',
#    'lower',
#    'avulsion',
#    'olio',
#    'padlock',
#    'spray',
#    'nonadmission',
#    'defect',
#    'rupture',
#    'personnel',
#    'affix',
#    'ace',
#    'nulli',
#    'twig',
#    'superposition',
#    'sharpness',
#    'molecule',
#    'reach',
#    'superfetation',
#    'corrugated',
#    'texture',
#    'other',
#    'extraneousness',
#    'sum',
#    'dozen',
#    'caldron',
#    'mode',
#    'cabestro',
#    'inseparableness',
#    'joinder',
#    'similar',
#    'jumble',
#    'phr',
#    'whit',
#    'circumcision',
#    'be',
#    'completeness',
#    'cantlet',
#    'anastomosis',
#    'equilibration',
#    'diremption',
#    'next',
#    'greatness',
#    'fraction',
#    'installment',
#    'heeltap',
#    'annexe',
#    'greater',
#    'salmagundi',
#    'agglutination',
#    'match',
#    'bush',
#    'chief',
#    'shaving',
#    'disseverance',
#    'strap',
#    'joining',
#    'corpuscle',
#    'leavings',
#    'hotchpot',
#    'moorings',
#    'readjustment',
#    'smallness',
#    'saturation',
#    'chunk',
#    'restraint',
#    'snippet',
#    'skewer',
#    'omnium',
#    'coherence',
#    'atonement',
#    'brother',
#    'ladino',
#    'imperfection',
#    'catalo',
#    'communication',
#    'infinity',
#    'culmination',
#    'water',
#    'perfection',
#    'race',
#    'pay',
#    'caret',
#    'high',
#    'pares',
#    'standing',
#    'bandage',
#    'zambo',
#    'integrant',
#    'skeleton',
#    'allotment',
#    'swear',
#    'rivet',
#    'survival',
#    'resection',
#    'neutralization',
#    'agglomeration',
#    'blending',
#    'solidity',
#    'compartition',
#    'quintroon',
#    'division',
#    'noose',
#    'paul',
#    'latch',
#    'melange',
#    'indivisibility',
#    'demand',
#    'course',
#    'rest',
#    'worth',
#    'density',
#    'hardly',
#    'separation',
#    'wreck',
#    'means',
#    'grout',
#    'extrinsicality',
#    'annex',
#    'emigrant',
#    'conception',
#    'overplus',
#    'dee',
#    'difference',
#    'dimensions',
#    'putty',
#    'mestizo',
#    'portion',
#    'disconnection',
#    'newcomer',
#    'immigrant',
#    'orts',
#    'collectiveness',
#    'anticlimax',
#    'griffe',
#    'riband',
#    'tertium',
#    'fragment',
#    'advantage',
#    'afterglow',
#    'iron',
#    'continuation',
#    'relic',
#    'uncleanness',
#    'wafer',
#    'batch',
#    'nonaddition',
#    'brass',
#    'choose',
#    'fissure',
#    'equalization',
#    'compeer',
#    'without',
#    'sophistication',
#    'fastening',
#    'integration',
#    'noncompletion',
#    'minuend',
#    'adherence',
#    'quarteron',
#    'tissue',
#    'surplusage',
#    'reinforcement',
#    'ordination',
#    'main',
#    'sip',
#    'similarity',
#    'laxity',
#    'plus',
#    'stubble',
#    'disassociation',
#    'residue',
#    'coition',
#    'stucco',
#    'gain',
#    'ends',
#    'flood',
#    'gatherum',
#    'fiber',
#    'girder',
#    'buckle',
#    'compromise',
#    'tendril',
#    'mosaic',
#    'cable',
#    'luxation',
#    'birdlime',
#    'caste',
#    'totalness',
#    'preclusion',
#    'equipoise',
#    'unimportance',
#    'recision',
#    'entirety',
#    'compages',
#    'marabou',
#    'alpha',
#    'polak',
#    'triton',
#    'inter',
#    'octoroon',
#    'interlarding',
#    'bit',
#    'ribbon',
#    'tie',
#    'crumb',
#    'breadth',
#    'speck',
#    'junction',
#    'africander',
#    'dispersion',
#    'roller',
#    'particular',
#    'wing',
#    'severalty',
#    'bond',
#    'jot',
#    'allness',
#    'gum',
#    'contents',
#    'cartload',
#    'symphysis',
#    'loosening',
#    'standoff',
#    'sexual',
#    'treenail',
#    'extension',
#    'ribband',
#    'quo',
#    'great',
#    'withdrawal',
#    'ramification',
#    'screed',
#    'morsel',
#    'equation',
#    'iv',
#    'reduction',
#    'enlargement',
#    'universal',
#    'superiority',
#    'extenuation',
#    'grappling',
#    'reunion',
#    'armful',
#    'wash',
#    'tenor',
#    'ultra',
#    'solidarity',
#    'trikumia',
#    'detritus',
#    'meanness',
#    'divulsion',
#    'rope',
#    'for',
#    'assemblage',
#    'tenuity',
#    'gore',
#    'completion',
#    'taking',
#    'inch',
#    'thong',
#    'scruple',
#    'supplement',
#    'mere',
#    'quid',
#    'intruder',
#    'term',
#    'decline',
#    'filament',
#    'garter',
#    'cleavage',
#    'retaliation',
#    'excerpta',
#    'glue',
#    'dutchman',
#    'measure',
#    'might',
#    'insulation',
#    'contraction',
#    'concrete',
#    'tackle',
#    'among',
#    'mash',
#    'modicum',
#    'lessening',
#    'split',
#    'freedom',
#    'lamina',
#    'hulk',
#    'sprig',
#    'dividend',
#    'closeness',
#    'ward',
#    'inosculation',
#    'abatement',
#    'paring',
#    'trappings',
#    'count',
#    'branch',
#    'saturity',
#    'quantum',
#    'denominator',
#    'issue',
#    'totality',
#    'result',
#    'moderation',
#    'cantle',
#    'constitution',
#    'ideal',
#    'dum',
#    'superplus',
#    'animalcule',
#    'eye',
#    'tweedle',
#    'bur',
#    'deficiency',
#    'mark',
#    'griffo',
#    'simpleness',
#    'lacuna',
#    'cheesepairings',
#    'copula',
#    'coalescence',
#    'deal',
#    'mortar',
#    'element',
#    'saw',
#    'range',
#    'gradation',
#    'disjecta',
#    'climax',
#    'abruption',
#    'equivalence',
#    'clasp',
#    'separability',
#    'addendum',
#    'adhesiveness',
#    'divorce',
#    'collop',
#    'lump',
#    'educt',
#    'dead',
#    'snack',
#    'relaxation',
#    'sop',
#    'scission',
#    'vinculum',
#    'bias',
#    'least',
#    'rigging',
#    'noninclusion',
#    'not',
#    'abscission',
#    'catalysis',
#    'pot',
#    'nonpreparation',
#    'slip',
#    'clipping',
#    'shrinking',
#    'congress',
#    'globule',
#    'bole',
#    'intermixture',
#    'novus',
#    'interloper',
#    'granule',
#    'mass',
#    'exile',
#    'end',
#    'store',
#    'level',
#    'circular',
#    'off',
#    'commutation',
#    'waste',
#    'gap',
#    'paucity',
#    'interval',
#    'stock',
#    'torso',
#    'minim',
#    'disruption',
#    'sacatra',
#    'knot',
#    'caesura',
#    'mitigation',
#    'inclusion',
#    'additament',
#    'zebrule',
#    'transfusion',
#    'cross',
#    'load',
#    'infiltration',
#    'incision',
#    'declension',
#    'disintegration',
#    'article',
#    'peck',
#    'drawn',
#    'prop',
#    'alienism',
#    'parcel',
#    'flap',
#    'copulation',
#    'lobe',
#    'removal',
#    'middle',
#    'pivot',
#    'paste',
#    'terceron',
#    'sticking',
#    'quality',
#    'salad',
#    'detent',
#    'section',
#    'ambigu',
#    'profit',
#    'amalgam',
#    'commixion',
#    'rescission',
#    'anatomy',
#    'predicament',
#    'quits',
#    'abstraction',
#    'impregnation',
#    'compound',
#    'homogeneity',
#    'cafuzo',
#    'dependence',
#    'equiponderance',
#    'nutshell',
#    'vincture',
#    'all',
#    'mean',
#    'conjunction',
#    'class',
#    'filling',
#    'maximum',
#    'ligation',
#    'sufficiency',
#    'passage',
#    'ebbing',
#    'staple',
#    'incorporation',
#    'caliber',
#    'inclination',
#    'object',
#    'tinge',
#    'mortise',
#    'debris',
#    'bracket',
#    'offshoot',
#    'make',
#    'sup',
#    'crackajack',
#    'abrasion',
#    'ligament',
#    'medley',
#    'median',
#    'yarn',
#    'tightness',
#    'finite',
#    'connection',
#    'admission',
#    'weight',
#    'joint',
#    'one',
#    'instrument',
#    'minutiae',
#    'annexationist',
#    'omega',
#    'best',
#    'snip',
#    'segregation',
#    'island',
#    'nobility',
#    'severance',
#    'tenderfoot',
#    'finiteness',
#    'interpolation',
#    'crasis',
#    'bumper',
#    'bridge',
#    'compartment',
#    'fission',
#    'vanishing',
#    'spread',
#    'member',
#    'morceau',
#    'thing',
#    'chip',
#    'enormity',
#    'adjective',
#    'flitter',
#    'inferiority',
#    'lock',
#    'remainder',
#    'miscellany',
#    'miscegenation',
#    'thought',
#    'decrement',
#    'sauce',
#    'deficit',
#    'ratio',
#    'immaturity',
#    'measures',
#    'integer',
#    'miter',
#    'medium',
#    'guy',
#    'conglomerate',
#    'body',
#    'sight',
#    'tack',
#    'dight',
#    'mate',
#    'repudiation',
#    'adjustment',
#    'decrease',
#    'lead',
#    'homo',
#    'paragraph',
#    'cut',
#    'ballast',
#    'depreciation',
#    'trifle',
#    'absorption',
#    'drop',
#    'clamp',
#    'sprinkling',
#    'offset',
#    'anything',
#    'tincture',
#    'superjunction',
#    'poise',
#    'lappet',
#    'rein',
#    'consolidation',
#    'material',
#    'outsider',
#    'running',
#    'looseness',
#    'essential',
#    'membra',
#    'benjamin',
#    'arm',
#    'viscum',
#    'wop',
#    'dilaceration',
#    'withy',
#    'record',
#    'wire',
#    'oddments',
#    'fracture',
#    'foreign',
#    'sector',
#    'foreigner',
#    'county',
#    'adhesion',
#    'comprehension',
#    'supernumerary',
#    'details',
#    'almost',
#    'commissure',
#    'debt',
#    'tenacity',
#    'mouthful',
#    'fritter',
#    'fusion',
#    'hole',
#    'mathesis',
#    'barrel',
#    'immiscibility',
#    'pasticcio',
#    'hook',
#    'soldering',
#    'scintilla',
#    'insertion',
#    'retrenchment',
#    'stump',
#    'principal',
#    'accessory',
#    'pewter',
#    'standard',
#    'discontinuity',
#    'garbling',
#    'seposition',
#    'coarctation',
#    'break',
#    'cofferdam',
#    'tail',
#    'augment',
#    'unity',
#    'accouplement',
#    'nail',
#    'up',
#    'partibility',
#    'nonincrease',
#    'formation',
#    'easterner',
#    'plaster',
#    'by',
#    'embroidery',
#    'common',
#    'accompaniment',
#    'piece',
#    'brimmer',
#    'slant',
#    'decomposition',
#    'braid',
#    'episode',
#    'mid',
#    'commixture',
#    'complement',
#    'excess',
#    'cleanness',
#    'defalcation',
#    'constituent',
#    'latchet',
#    'evenness',
#    'ruins',
#    'magma',
#    'increase',
#    'substance',
#    'subdivision',
#    'mote',
#    ...],
#   'ORDER': ['rudiments',
#    'continuity',
#    'monstrosity',
#    'butt',
#    'glance',
#    'premier',
#    'anomaly',
#    'sorting',
#    'extent',
#    'sample',
#    'tabulation',
#    'death',
#    'seron',
#    'contesseration',
#    'attroupement',
#    'disposition',
#    'frontispiece',
#    'specimen',
#    'drive',
#    'going',
#    'babel',
#    'bouche',
#    'quatre',
#    'diffusion',
#    'or',
#    'crossbreed',
#    'de',
#    'levee',
#    'home',
#    'extreme',
#    'primogenesis',
#    'budget',
#    'confusion',
#    'nature',
#    'herring',
#    'mulatto',
#    'suite',
#    'unconventionality',
#    'involvement',
#    'men',
#    'storm',
#    'persons',
#    'complexus',
#    'la',
#    'gathering',
#    'reception',
#    'verge',
#    'catholicity',
#    'anomalousness',
#    'coacervation',
#    'nonassemblage',
#    'association',
#    'focus',
#    'resort',
#    'cortege',
#    'outrider',
#    'ferment',
#    'concordia',
#    'denomination',
#    'kidney',
#    'pitch',
#    'fat',
#    'bud',
#    'nonsuch',
#    'rara',
#    'equator',
#    'individuality',
#    'discipline',
#    'maiden',
#    'subset',
#    'general',
#    'preface',
#    'team',
#    'peculiarity',
#    'deluge',
#    'at',
#    'epacme',
#    'social',
#    'irregularity',
#    'inversion',
#    'sphinx',
#    'selection',
#    'bellwether',
#    'destination',
#    'disunion',
#    'chain',
#    'prolepsis',
#    'van',
#    'fascicule',
#    'anteriority',
#    'disorderly',
#    'glomeration',
#    'grouping',
#    'queer',
#    'thousand',
#    'genesis',
#    'morning',
#    'wonder',
#    'blood',
#    'mess',
#    'voortrekker',
#    'red',
#    'set',
#    'noah',
#    'prefix',
#    'drift',
#    'hands',
#    'potch',
#    'neither',
#    'agreement',
#    'premises',
#    'aggregation',
#    'fag',
#    'bevy',
#    'wisp',
#    'disposal',
#    'mediety',
#    'pattern',
#    'cockatrice',
#    'tendency',
#    'good',
#    'work',
#    'chaos',
#    'even',
#    'bisection',
#    'sieve',
#    'entanglement',
#    'counts',
#    'diversity',
#    'conglobation',
#    'illustration',
#    'last',
#    'entry',
#    'shoal',
#    'disjunction',
#    'hodgepodge',
#    'particularization',
#    'precedence',
#    'fresh',
#    'curtain',
#    'to',
#    'eccentricity',
#    'metis',
#    'limit',
#    'commonness',
#    'prolusion',
#    'character',
#    'version',
#    'gordian',
#    'concourse',
#    'uniformity',
#    'sorts',
#    'category',
#    'mule',
#    'heelpiece',
#    'bonne',
#    'custom',
#    'original',
#    'way',
#    'close',
#    'regiment',
#    'state',
#    'party',
#    'narrow',
#    'hinny',
#    'expiration',
#    'manner',
#    'battle',
#    'germ',
#    'congregation',
#    'garde',
#    'string',
#    'stack',
#    'rumble',
#    'characteristic',
#    'irae',
#    'accumulation',
#    'extinction',
#    'propylaeum',
#    'half',
#    'do',
#    'music',
#    'midriff',
#    'kettle',
#    'appendage',
#    'extermination',
#    'natural',
#    'afterpiece',
#    'subordination',
#    'rank',
#    'clustering',
#    'kit',
#    'description',
#    'gang',
#    'cause',
#    'sequence',
#    'front',
#    'gateway',
#    'troop',
#    'devil',
#    'scale',
#    'case',
#    'determination',
#    'omphalos',
#    'round',
#    'exception',
#    'whip',
#    'muster',
#    'rise',
#    'worldwideness',
#    'fault',
#    'flock',
#    'foreword',
#    'spill',
#    'china',
#    'antecedence',
#    'world',
#    'himself',
#    'aftergame',
#    'mezzo',
#    'syntagma',
#    'termination',
#    'register',
#    'suit',
#    'tag',
#    'terminus',
#    'muddle',
#    'crew',
#    'afterpart',
#    'assignation',
#    'variety',
#    'condition',
#    'patchwork',
#    'precession',
#    'sequela',
#    'stage',
#    'sex',
#    'squad',
#    'free',
#    'architecture',
#    'dislocation',
#    'comitatus',
#    'oasis',
#    'webwork',
#    'mongrel',
#    'unicorn',
#    'organization',
#    'sorter',
#    'ordinary',
#    'genus',
#    'feather',
#    'principle',
#    'teratism',
#    'quotation',
#    'concatenation',
#    'of',
#    'station',
#    'kraken',
#    'sequel',
#    'point',
#    'anybody',
#    'outgrowth',
#    'anteposition',
#    'distribution',
#    'finality',
#    'graduation',
#    'generality',
#    'habituation',
#    'atlas',
#    'task',
#    'oddity',
#    'subtype',
#    'posteriority',
#    'labyrinth',
#    'lot',
#    'singularity',
#    'drove',
#    'calcutta',
#    'stour',
#    'multitude',
#    'line',
#    'forerunner',
#    'nave',
#    'universality',
#    'symmetry',
#    'congestion',
#    'opening',
#    'in',
#    'disorder',
#    'museology',
#    'nonconformity',
#    'before',
#    'lips',
#    'atajo',
#    'porch',
#    'roc',
#    'troupe',
#    'gaterum',
#    'aspersion',
#    'dropping',
#    'pelt',
#    'trait',
#    'combatants',
#    'following',
#    'embroilment',
#    'intermission',
#    'colligation',
#    'harbinger',
#    'aftergrowth',
#    'analysis',
#    'disarray',
#    'sort',
#    'bottom',
#    'grammar',
#    'suffix',
#    'desinence',
#    'incipience',
#    'nonesuch',
#    'mob',
#    'entrance',
#    'flotsam',
#    'heap',
#    'discomposure',
#    'tribe',
#    'pother',
#    'words',
#    'mouth',
#    'beaten',
#    'afterburden',
#    'appendix',
#    'centaur',
#    'column',
#    'hermaphrodite',
#    'complexity',
#    'generalization',
#    'exordium',
#    'company',
#    'conventionality',
#    'egg',
#    'dragnet',
#    'bing',
#    'persians',
#    'model',
#    'collocation',
#    'skirts',
#    'threshold',
#    'consummation',
#    'birth',
#    'ordo',
#    'infancy',
#    'spicilegium',
#    'jumble',
#    'head',
#    'rallying',
#    'levy',
#    'phr',
#    'catenation',
#    'grow',
#    'horde',
#    'loose',
#    'goal',
#    'tier',
#    'dissipation',
#    'nor',
#    'afterbirth',
#    'convolution',
#    'prolegomena',
#    'snowball',
#    'greatness',
#    'hattock',
#    'dissimilarity',
#    'frequency',
#    'shop',
#    'jungle',
#    'congeries',
#    'shock',
#    'brawl',
#    'pile',
#    'turning',
#    'implication',
#    'prodromos',
#    'cavalcade',
#    'anarchy',
#    'postscript',
#    'out',
#    'coagmentation',
#    'run',
#    'avis',
#    'elements',
#    'black',
#    'preparation',
#    'wake',
#    'hotch',
#    'imbroglio',
#    'uproar',
#    'omen',
#    'assortment',
#    'family',
#    'army',
#    'species',
#    'system',
#    'departure',
#    'fold',
#    'cahotage',
#    'omnium',
#    'thread',
#    'sheaf',
#    'idiocrasy',
#    'bedlam',
#    'hydra',
#    'water',
#    'retreat',
#    'intricacy',
#    'database',
#    'overture',
#    'pay',
#    'race',
#    'rubric',
#    'standing',
#    'inlet',
#    'allotment',
#    'inauguration',
#    'pas',
#    'agglomeration',
#    'solution',
#    'division',
#    'differentia',
#    'reading',
#    'strain',
#    'knock',
#    'interchange',
#    'school',
#    'course',
#    'move',
#    'gender',
#    'idiosyncrasy',
#    'conversazione',
#    'club',
#    'introduction',
#    'salvo',
#    'regards',
#    'example',
#    'bull',
#    'deorganization',
#    'conglomeration',
#    'fowl',
#    'particulars',
#    'spargefaction',
#    'whipper',
#    'hard',
#    'dawn',
#    'nucleus',
#    'waveson',
#    'normality',
#    'taxis',
#    'drawing',
#    'gable',
#    'tertium',
#    'convention',
#    'mulada',
#    'fish',
#    'continuation',
#    'page',
#    'difficulty',
#    'alternation',
#    'dissemination',
#    'disturbance',
#    'circumfusion',
#    'business',
#    'flesh',
#    'batch',
#    'broke',
#    'cradle',
#    'pyramid',
#    'outbreak',
#    'int',
#    'instance',
#    'herself',
#    'random',
#    'collectanea',
#    'garden',
#    'predecessor',
#    'tissue',
#    'equidistance',
#    'organism',
#    'je',
#    'saggittary',
#    'similarity',
#    'estrays',
#    'confounded',
#    'fraternity',
#    'normalcy',
#    'corrugation',
#    'vancourier',
#    'collector',
#    'gatherum',
#    'tuft',
#    'dies',
#    'flood',
#    'bale',
#    'rouser',
#    'varied',
#    'grace',
#    'normal',
#    'caste',
#    'derangement',
#    'alpha',
#    'specification',
#    'kind',
#    'termine',
#    'beneath',
#    'wicket',
#    'prodigy',
#    'file',
#    'footing',
#    'freak',
#    'fortuitous',
#    'mutant',
#    'second',
#    'misdemeanor',
#    'dispersion',
#    'rouleau',
#    'haunt',
#    'slut',
#    'speciality',
#    'secondariness',
#    'subdepartment',
#    'interruption',
#    'procrustean',
#    'creation',
#    'discord',
#    'gatherer',
#    'aberration',
#    'galaxy',
#    'distance',
#    'blow',
#    'milieu',
#    'hash',
#    'coup',
#    'constant',
#    'serpent',
#    'doomsday',
#    'blush',
#    'within',
#    'superiority',
#    'extremity',
#    'collective',
#    'reunion',
#    'initiative',
#    'prototype',
#    'epilogue',
#    'tenor',
#    'turmoil',
#    'sept',
#    'doom',
#    'unbroken',
#    'muss',
#    'for',
#    'chops',
#    'rhapsody',
#    'completion',
#    'assemblage',
#    'edge',
#    'violation',
#    'arriere',
#    'foreloper',
#    'mere',
#    'venue',
#    'quid',
#    'myself',
#    'term',
#    'array',
#    'pioneer',
#    'fate',
#    'embarcation',
#    'kin',
#    'lusus',
#    'rear',
#    'consecution',
#    'proem',
#    'propos',
#    'breed',
#    'infraction',
#    'slattern',
#    'compilation',
#    'conclave',
#    'mash',
#    'queue',
#    'onset',
#    'covey',
#    'disconformity',
#    'convulsion',
#    'prologue',
#    'flaw',
#    'lection',
#    'quoi',
#    'complexness',
#    'foreboding',
#    'personality',
#    'depot',
#    'ancestors',
#    'sockdolager',
#    'clan',
#    'conventicle',
#    'naturae',
#    'forelooper',
#    'inchoation',
#    'issue',
#    'midst',
#    'outlaw',
#    'crush',
#    'nondescript',
#    'outcast',
#    'brunt',
#    'rule',
#    'person',
#    'border',
#    'huddle',
#    'placenta',
#    'mark',
#    'table',
#    'mishmash',
#    'genealogy',
#    'horse',
#    'rush',
#    'fascine',
#    'convergence',
#    'naturalization',
#    'disjecta',
#    'perturbation',
#    'gradation',
#    'range',
#    'stamp',
#    'sea',
#    'phoenix',
#    'fire',
#    'parenthesis',
#    'diable',
#    'diaphragm',
#    'kink',
#    'series',
#    'digestion',
#    'herald',
#    'stalking',
#    'snowdrift',
#    'stand',
#    'hubbub',
#    'cumulation',
#    'prefigurement',
#    'lumber',
#    'want',
#    'courier',
#    'lump',
#    'exemplification',
#    'door',
#    'starting',
#    'postern',
#    'individuity',
#    'posse',
#    'brotherhood',
#    'consecutiveness',
#    'admired',
#    'acervation',
#    'merfolk',
#    'clump',
#    'rumpus',
#    'pot',
#    'remuda',
#    'bundle',
#    'dragon',
#    'congress',
#    'revolution',
#    'specificness',
#    'customary',
#    'monster',
#    'train',
#    'throng',
#    'mass',
#    'preference',
#    'atoms',
#    'prelude',
#    'things',
#    'end',
#    'eschatology',
#    'store',
#    'house',
#    'rhubarb',
#    'untidiness',
#    'fasces',
#    'off',
#    'gap',
#    'museum',
#    'conflux',
#    'interval',
#    'ancestry',
#    'interspersion',
#    'conformance',
#    'agitation',
#    'outset',
#    'tumble',
#    'roundup',
#    'waifs',
#    'offence',
#    'gavel',
#    'rudis',
#    'knot',
#    'technicality',
#    'their',
#    'haycock',
#    'caesura',
#    'complication',
#    'position',
#    'menagerie',
#    'propylon',
#    'impression',
#    'respersion',
#    'inclusion',
#    'group',
#    'conformity',
#    'digest',
#    'nib',
#    'halfway',
#    'multifariousness',
#    'room',
#    'pretty',
#    'parcel',
#    'fagot',
#    'trouble',
#    'tip',
#    'routine',
#    'peroration',
#    'unconformity',
#    'middle',
#    'sais',
#    'pudder',
#    'syntaxis',
#    'conclusion',
#    'abnormality',
#    'moles',
#    'dollar',
#    'wheels',
#    'section',
#    'observance',
#    'secundines',
#    'flying',
#    'predicament',
#    'finish',
#    'groundwork',
#    'compound',
#    'gnarl',
#    'collection',
#    'finale',
#    'row',
#    'fascicle',
#    'distributive',
#    'evolution',
#    'indigestaque',
#    'sect',
#    'all',
#    'mean',
#    'order',
#    'class',
#    'abc',
#    'cohue',
#    'fall',
#    'bunch',
#    'categories',
#    'object',
#    'discors',
#    'anarchism',
#    'source',
#    'alphabet',
#    'jetsam',
#    'codicil',
#    'catholicism',
#    'rarity',
#    'start',
#    'medley',
#    'designation',
#    'another',
#    'regularity',
#    'status',
#    'admission',
#    'speech',
#    'specialite',
#    'snorter',
#    'one',
#    'economy',
#    'minutiae',
#    'swan',
#    'informality',
#    'mermaid',
#    'omega',
#    'rudiment',
#    'domain',
#    'plan',
#    'antecedent',
#    'disorganization',
#    'everyone',
#    'prodromus',
#    'colophon',
#    'riot',
#    'spread',
#    'lesson',
#    'whose',
#    'thing',
#    'classification',
#    'law',
#    'taxonomy',
#    'sleave',
#    'headquarters',
#    'wedge',
#    'swarm',
#    'items',
#    'normalness',
#    'inferiority',
#    'dish',
#    'intermediate',
#    'protasis',
#    'miscellany',
#    'preamble',
#    'remove',
#    'stook',
#    'itself',
#    'raveling',
#    'libertine',
#    'precedent',
#    'tangled',
#    'lucidus',
#    'most',
#    'peg',
#    'antecedency',
#    'thoughts',
#    'succession',
#    'hell',
#    'progression',
#    'medium',
#    'conglomerate',
#    'body',
#    'sight',
#    'miracle',
#    'origin',
#    'outlines',
#    'particularity',
#    'method',
#    'rough',
#    'cyclops',
#    'medes',
#    'intrication',
#    'lead',
#    'prodrome',
#    'beginning',
#    'omniformity',
#    'habit',
#    'cut',
#    'pensee',
#    'tumult',
#    'indication',
#    'debut',
#    'fight',
#    'fasciculus',
#    'denouement',
#    'successor',
#    'thin',
#    'shoulders',
#    'cluster',
#    'nonconformist',
#    'membra',
#    'broken',
#    'host',
#    'chimera',
#    'bellmare',
#    'precursor',
#    'perplexity',
#    'record',
#    'more',
#    'deathblow',
#    'naturalness',
#    'fracas',
#    'finis',
#    'fracture',
#    'whirlwind',
#    'knarl',
#    'riddle',
#    'details',
#    'province',
#    'comprehension',
#    'voorlooper',
#    'hole',
#    'wyvern',
#    'multiformity',
#    'discontinuity',
#    'originality',
#    'litter',
#    'standard',
#    'pedigree',
#    'type',
#    'break',
#    'fatihah',
#    'tail',
#    'spheres',
#    'griffin',
#    'mix',
#    'periodicity',
#    'day',
#    'juste',
#    'leader',
#    'network',
#    'pleiades',
#    'worse',
#    'coming',
#    'after',
#    'affusion',
#    'endpoint',
#    'portal',
#    'confusedness',
#    'trail',
#    'up',
#    'corradiation',
#    'miscellaneousness',
#    'arrangement',
#    'corps',
#    'rendezvous',
#    'trysting',
#    'populousness',
#    'retinue',
#    'title',
#    'wilderness',
#    'truss',
#    'teratology',
#    'nucleolus',
#    'common',
#    'piece',
#    'press',
#    'heads',
#    'wife',
#    'place',
#    'priority',
#    'mid',
#    'episode',
#    'herd',
#    'seroon',
#    'minotaur',
#    'rising',
#    'divergence',
#    'mannerism',
#    'evection',
#    'new',
#    'cloud',
#    'period',
#    'composition',
#    'donnybrook',
#    'skein',
#    'fardel',
#    'force',
#    'fast',
#    'infringement',
#    'fair',
#    'million',
#    'abnormity',
#    'step',
#    'kingdom',
#    'familiarity',
#    'breach',
#    'apportionment',
#    'pack',
#    'expiry',
#    'self',
#    'qualification',
#    'usage',
#    'weirdo',
#    'le',
#    'track',
#    'scattering',
#    'coacervate',
#    'subordinancy',
#    'elucidation',
#    'avant',
#    'package',
#    'ruction',
#    'bear',
#    'consecutive',
#    'successiveness',
#    'flow',
#    'crowd',
#    'coureur',
#    'concentration',
#    'synopsis',
#    'prevalence',
#    'as',
#    'gate',
#    'procession',
#    'merman',
#    'proemium',
#    'coil',
#    'aftercourse',
#    'aftercome',
#    'ladder',
#    'the',
#    'assembly',
#    ...],
#   'NUMBER': ['listing',
#    'census',
#    'trine',
#    'deuce',
#    'few',
#    'thesaurus',
#    'analytical',
#    'multiple',
#    'coefficient',
#    'triennium',
#    'long',
#    'nothing',
#    'gross',
#    'divisor',
#    'index',
#    'absence',
#    'or',
#    'de',
#    'hanger',
#    'triplet',
#    'fare',
#    'decimation',
#    'irrational',
#    'multiplicand',
#    'power',
#    'quadrant',
#    'appurtenance',
#    'quadriform',
#    'redundancy',
#    'ternion',
#    'directory',
#    'leash',
#    'exponent',
#    'product',
#    'association',
#    'trefoil',
#    'cortege',
#    'hundred',
#    'void',
#    'roots',
#    'ingemination',
#    'algebraist',
#    'duplication',
#    'individuality',
#    'raisonne',
#    'team',
#    'eighty',
#    'tallies',
#    'reiteration',
#    'counter',
#    'proportion',
#    'halving',
#    'carte',
#    'thousand',
#    'records',
#    'statistician',
#    'red',
#    'cube',
#    'minority',
#    'bushel',
#    'story',
#    'symbol',
#    'infinitude',
#    'recurrence',
#    'fifty',
#    'quinquesection',
#    'fluent',
#    'quint',
#    'elimination',
#    'brace',
#    'part',
#    'seclusion',
#    'bevy',
#    'three',
#    'null',
#    'nichts',
#    'bisection',
#    'rhabdology',
#    'decade',
#    'shoal',
#    'disjunction',
#    'integral',
#    'reckoning',
#    'menu',
#    'lexicon',
#    'cwt',
#    'brood',
#    'algebra',
#    'modulus',
#    'terrier',
#    'on',
#    'individual',
#    'branching',
#    'fork',
#    'fourscore',
#    'vi',
#    'trey',
#    'geometrical',
#    'nobody',
#    'abacus',
#    'associate',
#    'multiplication',
#    'estimation',
#    'fluxion',
#    'electronic',
#    'span',
#    'unification',
#    'half',
#    'adjunct',
#    'fellow',
#    'appendage',
#    'prospectus',
#    'triskelion',
#    'quadrivium',
#    'triunity',
#    'profusion',
#    'told',
#    'duplicity',
#    'shadow',
#    'guiness',
#    'certain',
#    'co',
#    'concomitant',
#    'civil',
#    'round',
#    'practice',
#    'blue',
#    'biplicity',
#    'quart',
#    'nul',
#    'muster',
#    'diffuseness',
#    'dyad',
#    'ledger',
#    'account',
#    'yoke',
#    'numeration',
#    'flock',
#    'triangle',
#    'world',
#    'checklist',
#    'pan',
#    'cipher',
#    'register',
#    'cadaster',
#    'service',
#    'milliard',
#    'majority',
#    'subtraction',
#    'costs',
#    'infiniteness',
#    'catalog',
#    'context',
#    'draught',
#    'conjugation',
#    'subtrahend',
#    'seven',
#    'catalogue',
#    'numerality',
#    'of',
#    'spouse',
#    'tautophony',
#    'invoice',
#    'spike',
#    'atlas',
#    'grand',
#    'quadrisection',
#    'equations',
#    'domesday',
#    'addition',
#    'gemini',
#    'indeterminate',
#    'drove',
#    'sestiad',
#    'napier',
#    'multitude',
#    'roll',
#    'triseme',
#    'unit',
#    'in',
#    'attribute',
#    'banzai',
#    'abacist',
#    'reproduction',
#    'zero',
#    'quarter',
#    'multiplicator',
#    'election',
#    'extraction',
#    'analysis',
#    'two',
#    'hive',
#    'triality',
#    'card',
#    'glossary',
#    'complex',
#    'suan',
#    'ace',
#    'company',
#    'coexistence',
#    'quintuplet',
#    'nought',
#    'oneness',
#    'tally',
#    'egg',
#    'other',
#    'sum',
#    'moiety',
#    'chiliad',
#    'dozen',
#    'fry',
#    'plurality',
#    'approximation',
#    'ban',
#    'weeding',
#    'phr',
#    'triplication',
#    'differential',
#    'companion',
#    'none',
#    'infinitesimal',
#    'fraction',
#    'auditor',
#    'gazetter',
#    'forty',
#    'almanach',
#    'greater',
#    'address',
#    'run',
#    'else',
#    'fourthing',
#    'tetrahedron',
#    'cadastre',
#    'numerator',
#    'reverberation',
#    'dactylonomy',
#    'plenty',
#    'doubling',
#    'army',
#    'bones',
#    'numbering',
#    'fold',
#    'cheeks',
#    'duality',
#    'shamrock',
#    'bifurcation',
#    'edition',
#    'slide',
#    'infinity',
#    'arithmetic',
#    'database',
#    'partnership',
#    'quad',
#    'tetract',
#    'baker',
#    'division',
#    'burden',
#    'enormous',
#    'geometry',
#    'rational',
#    'cinque',
#    'surd',
#    'qui',
#    'square',
#    'boundlessness',
#    'tripartition',
#    'song',
#    'refrain',
#    'statistics',
#    'several',
#    'difference',
#    'slipstick',
#    'harmonical',
#    'unsubstantiality',
#    'ame',
#    'dictionary',
#    'quadrangle',
#    'century',
#    'trigon',
#    'quotient',
#    'concomitance',
#    'quartering',
#    'dicker',
#    'pleonasm',
#    'conjugate',
#    'integration',
#    'prong',
#    'rifacimento',
#    'mixed',
#    'adding',
#    'trebleness',
#    'rehearsal',
#    'relative',
#    'trio',
#    'quadruplet',
#    'duet',
#    'hecatomb',
#    'jury',
#    'copartnership',
#    'quadruplication',
#    'totient',
#    'file',
#    'second',
#    'twice',
#    'imitation',
#    'contents',
#    'pollux',
#    'formula',
#    'transcendental',
#    'quadripartition',
#    'arithmetical',
#    'galaxy',
#    'numbers',
#    'great',
#    'triplopia',
#    'ramification',
#    'sarculation',
#    'fellows',
#    'scores',
#    'reduction',
#    'figure',
#    'trisula',
#    'logarithm',
#    'assemblage',
#    'lac',
#    'mathematician',
#    'quaternity',
#    'programmer',
#    'companionship',
#    'gotha',
#    'permilage',
#    'clergy',
#    'four',
#    'array',
#    'battology',
#    'tetragon',
#    'calculating',
#    'thirteen',
#    'computation',
#    'measure',
#    'engine',
#    'eleven',
#    'flight',
#    'multiplier',
#    'covey',
#    'measurement',
#    'dichotomy',
#    'dividend',
#    'forking',
#    'renewal',
#    'tetrad',
#    'ninety',
#    'circulating',
#    'chart',
#    'denominator',
#    'rechauffe',
#    'bipartition',
#    'itemization',
#    'twins',
#    'rule',
#    'reduplication',
#    'tautology',
#    'table',
#    'years',
#    'returns',
#    'consort',
#    'sea',
#    'score',
#    'attendant',
#    'prime',
#    'myriad',
#    'poll',
#    'series',
#    'polygonal',
#    'quadrifoil',
#    'echo',
#    'trillion',
#    'reciprocal',
#    'dead',
#    'computer',
#    'ten',
#    'digit',
#    'pyramidal',
#    'vocabulary',
#    'eradication',
#    'not',
#    'repetition',
#    'call',
#    'numerous',
#    'quatrefoil',
#    'calculus',
#    'almanac',
#    'quincux',
#    'dimidiation',
#    'five',
#    'paucity',
#    'function',
#    'buddy',
#    'tableau',
#    'determinate',
#    'chimes',
#    'rectangle',
#    'trinity',
#    'quaternion',
#    'antilogarithm',
#    'quartern',
#    'peck',
#    'tierce',
#    'geometer',
#    'exiguity',
#    'factor',
#    'cash',
#    'divarication',
#    'octal',
#    'pair',
#    'section',
#    'check',
#    'siamese',
#    'quadrature',
#    'differentiation',
#    'bead',
#    'couple',
#    'zilch',
#    'triskele',
#    'quadrupole',
#    'checker',
#    'times',
#    'evolution',
#    'man',
#    'iteration',
#    'all',
#    'harping',
#    'castor',
#    'enumeration',
#    'tripod',
#    'rarity',
#    'who',
#    'nixie',
#    'zippo',
#    'aliquot',
#    'trident',
#    'colleague',
#    'fluxions',
#    'abstract',
#    'one',
#    'differences',
#    'subdichotomy',
#    'maniple',
#    'decimal',
#    'numerosity',
#    'interpolation',
#    'trinomial',
#    'permutation',
#    'seventy',
#    'swarm',
#    'traveller',
#    'book',
#    'algorism',
#    'millennium',
#    'dualism',
#    'farrow',
#    'supputation',
#    'trireme',
#    'ratio',
#    'recension',
#    'nest',
#    'biformity',
#    'algorithm',
#    'integer',
#    'succession',
#    'progression',
#    'lloyd',
#    'sight',
#    'mate',
#    'escort',
#    'reappearance',
#    'nautical',
#    'fractional',
#    'figurate',
#    'quartet',
#    'hundredweight',
#    'billion',
#    'fourth',
#    'host',
#    'infrequency',
#    'multiplicity',
#    'record',
#    'notation',
#    'inverted',
#    'calculation',
#    'summation',
#    'root',
#    'diptych',
#    'solitude',
#    'farthing',
#    'perpetuity',
#    'soul',
#    'accessory',
#    'litter',
#    'ritornello',
#    'centenary',
#    'unity',
#    'periodicity',
#    'recapitulation',
#    'cartulary',
#    'base',
#    'goose',
#    'old',
#    'twenty',
#    'recursion',
#    'by',
#    'restoration',
#    'common',
#    'accompaniment',
#    'eight',
#    'wife',
#    'tale',
#    'drumming',
#    'tetrapod',
#    'herd',
#    'complement',
#    'plum',
#    'coefficiency',
#    'capitation',
#    'outline',
#    'polarity',
#    'new',
#    'cloud',
#    'arithmetician',
#    'binary',
#    'handful',
#    'combination',
#    'friend',
#    'hexadecimal',
#    'calculator',
#    'million',
#    'small',
#    'naught',
#    'word',
#    'repetend',
#    'sixty',
#    'partner',
#    'triad',
#    'zip',
# ...
#    'lapse',
#    'fortune',
#    'ankylosis',
#    'vicinism',
#    'battledore',
#    'current',
#    'permutation',
#    'spasm',
#    'recoil',
#    'thing',
#    'vicissitudes',
#    'law',
#    'dish',
#    'lock',
#    'atavism',
#    'tit',
#    'destruction',
#    'modulation',
#    'harlequin',
#    'mood',
#    'transmutation',
#    'medes',
#    'reciprocation',
#    'disquietude',
#    'drop',
#    'changeableness',
#    'minute',
#    'restlessness',
#    'finis',
#    'innovation',
#    'unchangeableness',
#    'unchangeability',
#    'retrogression',
#    'recombination',
#    'future',
#    'versatility',
#    'break',
#    'legerdemain',
#    'earthquake',
#    'periodicity',
#    'day',
#    'sweeping',
#    'after',
#    'up',
#    'developing',
#    'viii',
#    'cessation',
#    'restoration',
#    'stiffness',
#    'episode',
#    'transference',
#    'full',
#    'mutability',
#    'semicolon',
#    'period',
#    'combination',
#    'bureau',
#    'incident',
#    'lull',
#    'qualification',
#    'ethiopia',
#    'assimilation',
#    'affairs',
#    'purchase',
#    'jump',
#    'vitality',
#    'unstable',
#    'the',
#    'equilibrium',
#    'fluctuation',
#    'truce',
#    'replacement',
#    'change',
#    'intermutation',
#    'accidents',
#    'shuffling',
#    'stability',
#    'vicissitude',
#    'variation'],
#   'CAUSATION': ['action',
#    'sabotage',
#    'weather',
#    'competency',
#    'pacification',
#    'virgilianae',
#    'firstfruits',
#    'flip',
#    'sperm',
#    'tree',
#    'albumen',
#    'fulmen',
#    'tower',
#    'papa',
#    'long',
#    'biblioclasm',
#    'upshot',
#    'metal',
#    'nihil',
#    'lottery',
#    'loss',
#    'leaven',
#    'patriarchs',
#    'antispasmodic',
#    'author',
#    'moderator',
#    'apotheosis',
#    'or',
#    'procreator',
#    'interaction',
#    'de',
#    'inertia',
#    'plot',
#    'steel',
#    'home',
#    'inability',
#    'tiger',
#    'creator',
#    'orgasm',
#    'causes',
#    'nature',
#    'exhaustion',
#    'annihilation',
#    'power',
#    'nerve',
#    'conducement',
#    'blanket',
#    'cell',
#    'union',
#    'harvest',
#    'la',
#    'omnipotence',
#    'endowment',
#    'storm',
#    'lullaby',
#    'support',
#    'structure',
#    'constancy',
#    'grandchild',
#    'contingence',
#    'product',
#    'interworking',
#    'key',
#    'shog',
#    'rose',
#    'ferment',
#    'workmanship',
#    'smash',
#    'fat',
#    'bud',
#    'aftercrop',
#    'capacity',
#    'intensity',
#    'child',
#    'inutility',
#    'equal',
#    'obstinacy',
#    'latency',
#    'destroying',
#    'sloth',
#    'fructification',
#    'motherhood',
#    'chance',
#    'paterfamilias',
#    'incapacity',
#    'hydroelectric',
#    'gymnast',
#    'beast',
#    'contrariety',
#    'irresolution',
#    'eater',
#    'mobile',
#    'impuissance',
#    'genesis',
#    'productiveness',
#    'blood',
#    'downfall',
#    'temperament',
#    'conatus',
#    'gun',
#    'opposition',
#    'sand',
#    'set',
#    'telum',
#    'tempest',
#    'consilience',
#    'antagonism',
#    'inflorescence',
#    'resultant',
#    'razzia',
#    'forbears',
#    'ferocity',
#    'drift',
#    'inertiae',
#    'agreement',
#    'agent',
#    'premises',
#    'failure',
#    'inertness',
#    'resistance',
#    'blusterer',
#    'tendency',
#    'obstetrics',
#    'epigenesis',
#    'work',
#    'property',
#    'quickening',
#    'ability',
#    'predominancy',
#    'oak',
#    'goliath',
#    'inefficiency',
#    'invalidation',
#    'ground',
#    'disablement',
#    'abba',
#    'stem',
#    'executioner',
#    'capability',
#    'valeant',
#    'brood',
#    'to',
#    'ebullition',
#    'on',
#    'bouleversement',
#    'origo',
#    'odds',
#    'causation',
#    'trunk',
#    'mandragora',
#    'unreactivity',
#    'letter',
#    'counteraction',
#    'thermonuclear',
#    'formativus',
#    'final',
#    'state',
#    'multiplication',
#    'butcha',
#    'ferre',
#    'bookmaking',
#    'exercise',
#    'germ',
#    'finger',
#    'virtue',
#    'subversion',
#    'spring',
#    'chapter',
#    'keenness',
#    'panels',
#    'adynamy',
#    'origination',
#    'maker',
#    'conduciveness',
#    'extinction',
#    'malignity',
#    'archebiosis',
#    'uberty',
#    'mamma',
#    'pullulation',
#    'causiticity',
#    'consequence',
#    'unproductivity',
#    'events',
#    'cause',
#    'sequence',
#    'emasculation',
#    'foundation',
#    'inexcitability',
#    'dissolution',
#    'spawn',
#    'olive',
#    'flowing',
#    'devil',
#    'delabrement',
#    'lenity',
#    'development',
#    'accident',
#    'anaphrodisia',
#    'yang',
#    'scion',
#    'growth',
#    'quiescence',
#    'grandfather',
#    'strength',
#    'vein',
#    'voltaism',
#    'muscle',
#    'rage',
#    'flaccidity',
#    'flash',
#    'himself',
#    'pan',
#    'shipwreck',
#    'indocility',
#    'remission',
#    'interest',
#    'heterogamy',
#    'bustle',
#    'dissilience',
#    'metron',
#    'predisposition',
#    'athlete',
#    'bone',
#    'raccroc',
#    'generation',
#    'detonation',
#    'vantage',
#    'brute',
#    'stoutness',
#    'architecture',
#    'impetuosity',
#    'tap',
#    'life',
#    'organization',
#    'play',
#    'parturition',
#    'torpor',
#    'principle',
#    'production',
#    'creature',
#    'asthenia',
#    'breaking',
#    'block',
#    'of',
#    'heir',
#    'oogenesis',
#    'tone',
#    'point',
#    'radicle',
#    'outburst',
#    'reaction',
#    'semen',
#    'outgrowth',
#    'heterogenesis',
#    'atlas',
#    'demolishment',
#    'parthenogenesis',
#    'deterioration',
#    'conductivity',
#    'vera',
#    'causality',
#    'adamant',
#    'fabrication',
#    'founder',
#    'pith',
#    'recusent',
#    'line',
#    'handiwork',
#    'virtility',
#    'dummy',
#    'gentleness',
#    'ii',
#    'sprain',
#    'in',
#    'gravity',
#    'punish',
#    'disorder',
#    'alecto',
#    'control',
#    'eddish',
#    'resolution',
#    'attribute',
#    'maternity',
#    'circumstance',
#    'acrobat',
#    'prepollence',
#    'brutum',
#    'fulcrum',
#    'explosion',
#    'reproduction',
#    'works',
#    'seasoning',
#    'bringing',
#    'iconoclast',
#    'eboulement',
#    'abolition',
#    'indirect',
#    'opiate',
#    'accidentalness',
#    'premices',
#    'that',
#    'skill',
#    'flowering',
#    'brain',
#    'aftergrowth',
#    'extraction',
#    'potential',
#    'cast',
#    'compensation',
#    'rationale',
#    'architect',
#    'inventor',
#    'ariston',
#    'palsy',
#    'confinement',
#    'authority',
#    'imputation',
#    'beldame',
#    'golden',
#    'puff',
#    'mollycoddle',
#    'xenogeny',
#    'preponderance',
#    'bent',
#    'tribe',
#    'weakling',
#    'fertility',
#    'pithiness',
#    'jiva',
#    'hand',
#    'radical',
#    'strengthening',
#    'between',
#    'progenitor',
#    'hotbed',
#    'paralysis',
#    'leaning',
#    'intention',
#    'permanence',
#    'overthrow',
#    'coin',
#    'fecundation',
#    'superfetation',
#    'egg',
#    'gaming',
#    'quatre',
#    'agency',
#    'putting',
#    'callithump',
#    'eidoloclast',
#    'inefficacy',
#    'weakness',
#    'sway',
#    'birth',
#    'galvanism',
#    'head',
#    'auspices',
#    'reason',
#    'phr',
#    'desolation',
#    'lustihood',
#    'magnetism',
#    'wheel',
#    'telegony',
#    'elasticity',
#    'counterblast',
#    'situation',
#    'thunderstorm',
#    'synergy',
#    'shock',
#    'pile',
#    'consumption',
#    'turning',
#    'mainspring',
#    'sinews',
#    'madcap',
#    'run',
#    'contingency',
#    'heredity',
#    'pressure',
#    'luxuriance',
#    'uproar',
#    'howling',
#    'family',
#    'primum',
#    'coagency',
#    'validity',
#    'toss',
#    'powder',
#    'eumerogenesis',
#    'voluntary',
#    'adventure',
#    'coincidence',
#    'renitency',
#    'direction',
#    'humeri',
#    'restraint',
#    'devastation',
#    'straight',
#    'aptitude',
#    'font',
#    'thread',
#    'idiocrasy',
#    'operation',
#    'stirps',
#    'publication',
#    'susceptibility',
#    'edition',
#    'aftermath',
#    'instrumentality',
#    'water',
#    'hydra',
#    'occasion',
#    'dice',
#    'invalidity',
#    'race',
#    'pay',
#    'partnership',
#    'high',
#    'feats',
#    'languor',
#    'favorable',
#    'passivity',
#    'demulcent',
#    'neutralization',
#    'biogenesis',
#    'nihilist',
#    'acrimony',
#    'sprit',
#    'rare',
#    'ableness',
#    'tombola',
#    'deliquium',
#    'childbirth',
#    'strain',
#    'knock',
#    'idiosyncrasy',
#    'berserk',
#    'debility',
#    'wreck',
#    'milch',
#    'opus',
#    'rabbit',
#    'mover',
#    'statistics',
#    'inclemency',
#    'vacuolization',
#    'why',
#    'biblioclast',
#    'suction',
#    'nucleus',
#    'productivity',
#    'iron',
#    'ascendency',
#    'demolition',
#    'apart',
#    'enervation',
#    'perdition',
#    'resultance',
#    'consent',
#    'cradle',
#    'outbreak',
#    'cachexy',
#    'crop',
#    'father',
#    'squall',
#    'bloodlessness',
#    'physical',
#    'disqualification',
#    'sortes',
#    'live',
#    'inactivity',
#    'propagation',
#    'et',
#    'random',
#    'fragility',
#    'delicacy',
#    'revivification',
#    'palingenesis',
#    'excitation',
#    'together',
#    'honey',
#    'utility',
#    'son',
#    'main',
#    'violence',
#    'firstlings',
#    'collapse',
#    'calmness',
#    'oeuvre',
#    'incapability',
#    'killer',
#    'applicability',
#    'gas',
#    'heirs',
#    'construction',
#    'quaker',
#    'aphrodisia',
#    'sonship',
#    'vox',
#    'excitability',
#    'ascription',
#    'fountain',
#    'imbelle',
#    'outrage',
#    'invigoration',
#    'shoot',
#    'debacle',
#    'burst',
#    'fertilization',
#    'dilapidation',
#    'pregnancy',
#    'footing',
#    'superman',
#    'bit',
#    'wastefulness',
#    'second',
#    'forefathers',
#    'tisiphone',
#    'abrogation',
#    'fountainhead',
#    'hindrance',
#    'remote',
#    'efficiency',
#    'creation',
#    'cow',
#    'fons',
#    'exasperation',
#    'back',
#    'offspring',
#    'blow',
#    'possibility',
#    'great',
#    'explanation',
#    'ramification',
#    'milieu',
#    'fickle',
#    'breaks',
#    'fabric',
#    'coup',
#    'paternity',
#    'accounting',
#    'turn',
#    'wimp',
#    'maintenance',
#    'humor',
#    'refocillation',
#    'paper',
#    'prepotency',
#    'decrepitude',
#    'turmoil',
#    'haphazard',
#    'sept',
#    'doom',
#    'dam',
#    'derivation',
#    'homogenesis',
#    'casualty',
#    'rope',
#    'for',
#    'pussycat',
#    'completion',
#    'crash',
#    'severity',
#    'edge',
#    'from',
#    'concert',
#    'paraffin',
#    'quid',
#    'temperateness',
#    'etiology',
#    'accouchement',
#    'building',
#    'germination',
#    'biogeny',
#    'fate',
#    'sideration',
#    'crux',
#    'heart',
#    'nisus',
#    'tidal',
#    'might',
#    'potentiality',
#    'measure',
#    'moderating',
#    'antaeus',
#    'vigor',
#    'achievement',
#    'breed',
#    'throe',
#    'carminative',
#    'poignancy',
#    'inhibition',
#    'convulsion',
#    'circuit',
#    'parent',
#    'renewal',
#    'land',
#    'clan',
#    'nidus',
#    'effect',
#    'grandsire',
#    'branch',
#    'issue',
#    'result',
#    'primogeniture',
#    'etymon',
#    'sinew',
#    'moderation',
#    'sobriety',
#    'affiliation',
#    'repression',
#    'establishment',
#    'speculation',
#    'gymnastics',
#    'orchiotomy',
#    'opium',
#    'erection',
#    'anaemia',
#    'flower',
#    'dullness',
#    'deficiency',
#    'electromagnetism',
#    'coinage',
#    'regeneration',
#    'originator',
#    'table',
#    'genealogy',
#    'mother',
#    'rush',
#    'wellhead',
#    'element',
#    'incompetence',
#    'modus',
#    'dynamics',
#    'perturbation',
#    'phoenix',
#    'suppression',
#    'unprofitableness',
#    'climax',
#    'leverage',
#    'assurance',
#    'athleticism',
#    'fire',
#    'diable',
#    'producer',
#    'prime',
#    'effervescence',
#    'demon',
#    'tocogony',
#    'probabilities',
#    'dead',
#    'atomic',
#    'acrospire',
#    'relaxation',
#    'dominance',
#    'havoc',
#    'hap',
#    'discharge',
#    'bias',
#    'apoplexy',
#    'inaptitude',
#    'dad',
#    'thews',
#    'sacrifice',
#    'ruin',
#    'cataclysm',
#    'derivative',
#    'assent',
#    'rumpus',
#    'condiment',
#    'cankerworm',
#    'lenitive',
#    'necessity',
#    'dragon',
#    'reign',
#    'youth',
#    'revolution',
#    'poppy',
#    'extirpation',
#    'posterity',
#    'wrack',
#    'ancestor',
#    'liableness',
#    'entelechy',
#    'rail',
#    'end',
#    'delivery',
#    'house',
#    'reanimation',
#    'proneness',
#    'puissance',
#    'physique',
#    'reed',
#    'waste',
#    'off',
#    'sire',
#    'poverty',
#    'volcano',
#    'function',
#    'causa',
#    'stock',
#    'attribution',
#    'well',
#    'atony',
#    'ancestry',
#    'sprout',
#    'disruption',
#    'agitation',
#    'cantharides',
#    'paroxysm',
#    'combinations',
#    'friction',
#    'mitigation',
#    'reprint',
#    'faculty',
#    'archegenesis',
#    'fermentation',
#    'fecundity',
#    'consanguinity',
#    'washout',
#    'declension',
#    'quicksilver',
#    'interference',
#    'exposure',
#    'undercurrents',
#    'disability',
#    'opposites',
#    'bluster',
#    'tails',
#    'stroke',
#    'pivot',
#    'procreation',
#    'megaera',
#    'parentage',
#    'quality',
#    'imbecility',
#    'genitor',
#    'grip',
#    'les',
#    'check',
#    'cooperation',
#    'infirmity',
#    'throw',
#    'infant',
#    'office',
#    'exertion',
#    'palliative',
#    'groundwork',
#    'impregnation',
#    'sterility',
#    'edifice',
#    'heiress',
#    'womb',
#    'row',
#    'contemporation',
#    'concurrence',
#    'evolution',
#    'balm',
#    'dependence',
#    'cartridge',
#    'all',
#    'mean',
#    'warren',
#    'class',
#    'performance',
#    'cogency',
#    'destroy',
#    'go',
#    'ineptitude',
#    'desert',
#    'fall',
#    'abiogenesis',
#    'des',
#    'inclination',
#    'source',
#    'impotence',
#    'almightiness',
#    'viva',
#    'effeminacy',
#    'proeterea',
#    'monogenesis',
#    'offshoot',
#    'cripple',
#    'refreshed',
#    'noble',
#    'medley',
#    'renovation',
#    'nuclear',
#    'infecundity',
#    'blast',
#    'feminality',
#    'influence',
#    'connection',
#    'propensity',
#    'mortua',
#    'weight',
#    'wet',
#    'domination',
#    'down',
#    'fortune',
#    'rudiment',
#    'mental',
#    'reference',
#    'electricity',
#    'liability',
#    'statics',
#    'uncertainty',
#    'disorganization',
#    'revival',
#    'metogenesis',
#    'riot',
#    'spasm',
#    'virulence',
#    'recoil',
#    'nursery',
#    'chip',
#    'eruption',
#    'clashing',
#    'indetermination',
#    'efficacy',
#    'activity',
#    'road',
#    'irrelevancy',
#    'procurement',
#    'occasioner',
#    'additivity',
#    'refreshment',
#    'camel',
#    'farrow',
#    'displosion',
#    'predominance',
#    'susceptivity',
#    'probability',
#    'vis',
#    'nest',
#    'destruction',
#    'gemmule',
#    'birthplace',
#    'ravage',
#    'protection',
#    'prostration',
#    'mood',
#    'origin',
#    'rough',
#    'cyclops',
#    'grit',
#    'right',
#    'maturation',
#    'beginning',
#    'reappearance',
#    'boisterousness',
#    'fathership',
#    'sustaining',
#    'hercules',
#    'cartes',
#    'creampuff',
#    'tonicity',
#    'labor',
#    'denouement',
#    'voltaic',
#    'wherefore',
#    'stamina',
#    'embryo',
#    'gift',
#    'arm',
#    'cachexia',
#    'spat',
#    'host',
#    'proclivity',
#    'luck',
#    'diaster',
#    'authorship',
#    'wire',
#    'hazard',
#    'apparent',
#    'arrish',
#    'descendant',
#    'fruit',
#    'softling',
#    'patronage',
#    'die',
#    'rowen',
#    'athletics',
#    'root',
#    'dint',
#    'solar',
#    'litter',
#    'sahara',
#    'pedigree',
#    'powerlessness',
#    'acritude',
#    'retroaction',
#    'break',
#    'yin',
#    'fury',
#    'earthquake',
#    'anodyne',
#    'juste',
#    'muff',
#    'woman',
#    'geniture',
#    'infertility',
#    'assassin',
#    'up',
#    'cards',
#    'attraction',
#    'old',
#    'fuel',
#    'softening',
#    'straw',
#    'formation',
#    'materfamilias',
#    'grandmother',
#    'wilderness',
#    'stir',
#    'tranquilization',
#    'restoration',
#    'common',
#    'heads',
#    'syncope',
#    'orchotomy',
#    'torrent',
#    'fatherhood',
#    'rising',
#    'polarity',
#    'aptness',
#    'new',
#    'giant',
#    'regrowth',
#    'bantling',
#    'force',
#    'causans',
#    'enablement',
#    'chances',
#    'filiation',
#    'bounce',
#    'midwifery',
#    'inertion',
#    'progeneration',
#    'bane',
#    'effort',
#    'vehemence',
#    'manufacture',
#    'operandi',
#    'qualification',
#    'unproductiveness',
#    'harshness',
#    'hit',
#    'assimilation',
#    'energy',
#    'le',
#    'digenesis',
#    'daughter',
#    'inactivation',
#    'blank',
#    'idoloclast',
#    'masturbation',
#    'purchase',
#    'dynamic',
#    'lever',
#    'sedative',
#    'vitality',
#    'travail',
#    'protoplasm',
#    'prevalence',
#    'seed',
#    'pungency',
#    'aftercome',
#    'the',
#    'hydraulic',
#    'radix',
#    'dessous',
#    'inanition',
#    'samson',
#    'commencement',
#    'milk',
#    'hysterics',
#    'fit',
#    'dysmerogenesis',
#    'alliance',
#    'lineage',
#    'gemination',
#    'plumule',
#    'inaction',
#    'merogenesis',
#    'incendiarism',
#    'wild',
#    'volley',
#    'turbulence',
#    'passion',
#    'theory',
#    'wind',
#    'proximate',
#    'potency',
#    'dissogeny',
#    'splutter',
#    'exacerbation',
#    'progeny',
#    ...]}}

# %% [markdown]
# Let's now save the hierarchy to a JSON file so that we can use it later.

# %%
# Save the hierarchy to a json file

with open('hierarchy_full.json', 'w') as file:
    json.dump(hierarchy, file)

# %% [markdown]
# ## Get Word Embeddings
#
# We can get different embedding models from various sources such as `GloVe`, `fastText`, `Word2Vec`, `BERT`.
# Even better from models such as `Gemini` or `OpenAI's` `text-embedding-3` which are more advanced and can provide better embeddings.
#
# In our case, we will use the brand new `Nomic` embeddings and more specifically the `nomic-embed-text-v1`,
# a text embedding model that supports variable output sizes.
# Source: [Nomic Embeddings Descriptions](https://docs.nomic.ai/atlas/models/text-embedding).
#
# Noteworthy to mention is that the `nomic-embed-text-v1` has a MTEB Score of 62.39 which is a very good score and close to the best score
# of the `text-embedding-3-large` which has a MTEB Score of 64.6 of OPENAI with the same input sequence length of 8192.
# However, the `nomic-embed-text-v1` is open-source and free to use, with a free trial of 1M tokens.
#
# > Note: The nomic-embed-text-v1.5 model was also tested,
# > but it did not provide better embeddings for the thesaurus according to some background tests for classification and clustering tasks.
#
# More Details here : [Nomic Embeddings](https://blog.nomic.ai/posts/nomic-embed-text-v1)

# %% [markdown]
# We will save two different versions of the embeddings.
# One will be embeddings with a task type specialized for clustering,
# and one will be embeddings with a task type specialized for classification.

# %% [markdown]
# The best option to use Nomic Embed is through the production-ready Nomic Embedding API.
#
# We can access the API via the python package `nomic` which is a Python client for the Nomic API.
# We will access them nomic library to get the embeddings for the words in the thesaurus.
#
# We can get a Nomic Atlas API key at [Nomic Atlas](https://atlas.nomic.ai/) after following the instructions to create an account and get the API key.
#
# Then in our terminal we need to run the following command to set the API key as an environment variable
# ```bash
# nomic login ```YOUR_API_KEY```
# ```
#
# With the above set, we can now get the embedding model and use it to get the embeddings for the words in the thesaurus.

# %% [markdown]
# Now we will store the embeddings to a vector database using `chromadb` which is a vector database that can store and query embeddings.

# %%
client = chromadb.PersistentClient(path="./chroma_db")
collection_clustering = client.get_or_create_collection(name="nomic_clustering_v1_new")
collection_classification = client.get_or_create_collection(name="nomic_classification_v1_new")

# %% [markdown]
# We will now retrieve the words along with their respective classes, divisions, and sections from the hierarchy and store them in a DataFrame.

# %%
with open("hierarchy_full.json", "r") as f:
    categories = json.load(f)

# %% [markdown]
# Let's now retrieve the words along with their respective classes, divisions, and sections from the hierarchy and store them in a DataFrame.

# %%
def json_to_df(categories, class_name=None, division_name='N/A'):
    df = pd.DataFrame()
    for key, value in categories.items():
        # Check if the current key is a class
        if 'divisions' in value and 'sections' in value:
            class_df = json_to_df(value['divisions'], class_name=key)
            section_df = json_to_df(value['sections'], class_name=key,
                                    division_name='N/A')  # Reset division for sections
            df = pd.concat([df, class_df, section_df], ignore_index=True)
        elif isinstance(value, dict):  # This is a division or a section
            if 'sections' in value:  # This is a division
                sub_df = json_to_df(value['sections'], class_name=class_name, division_name=key)
            else:  # This is a section without a division
                sub_df = json_to_df(value, class_name=class_name, division_name=division_name)
            df = pd.concat([df, sub_df], ignore_index=True)
        else:  # This is the actual list of words
            for word in value:
                new_row = pd.DataFrame({
                    "word": [word],
                    "class": [class_name],
                    "division": [division_name],
                    "section": [key],
                })
                df = pd.concat([df, new_row], ignore_index=True)
    return df


categories_df = json_to_df(categories)

# Displaying the first few rows of the DataFrame
categories_df
# Out:
#                word                                            class division  \
# 0             earth              WORDS EXPRESSING ABSTRACT RELATIONS      N/A
# 1          abeyance              WORDS EXPRESSING ABSTRACT RELATIONS      N/A
# 2            object              WORDS EXPRESSING ABSTRACT RELATIONS      N/A
# 3         principle              WORDS EXPRESSING ABSTRACT RELATIONS      N/A
# 4          inhesion              WORDS EXPRESSING ABSTRACT RELATIONS      N/A
# ...             ...                                              ...      ...
# 44124  resurrection  WORDS RELATING TO THE SENTIENT AND MORAL POWERS      N/A
# 44125          nine  WORDS RELATING TO THE SENTIENT AND MORAL POWERS      N/A
# 44126         bible  WORDS RELATING TO THE SENTIENT AND MORAL POWERS      N/A
# 44127     testament  WORDS RELATING TO THE SENTIENT AND MORAL POWERS      N/A
# 44128      guardian  WORDS RELATING TO THE SENTIENT AND MORAL POWERS      N/A
#
#                     section
# 0                 EXISTENCE
# 1                 EXISTENCE
# 2                 EXISTENCE
# 3                 EXISTENCE
# 4                 EXISTENCE
# ...                     ...
# 44124  RELIGIOUS AFFECTIONS
# 44125  RELIGIOUS AFFECTIONS
# 44126  RELIGIOUS AFFECTIONS
# 44127  RELIGIOUS AFFECTIONS
# 44128  RELIGIOUS AFFECTIONS
#
# [44129 rows x 4 columns]

# %% [markdown]
# We can now use the `nomic` library to get the embeddings for the words in the thesaurus with the `nomic-embed-text-v1` model
# and the specialized task type for clustering and classification.

# %%
nomic_embeddings_clustering = embed.text(
    texts=categories_df['word'].tolist(),
    model='nomic-embed-text-v1',
    task_type='clustering'
)

nomic_embeddings_classification = embed.text(
    texts=categories_df['word'].tolist(),
    model='nomic-embed-text-v1',
    task_type='classification'
)

# %% [markdown]
# Let's separate the different embeddings and store them in the DataFrame.

# %%
categories_df['embedding_clustering'] = nomic_embeddings_clustering['embeddings']
categories_df['embedding_classification'] = nomic_embeddings_classification['embeddings']

# %% [markdown]
# With that done, let's take a look at the DataFrame with the embeddings.

# %%
categories_df
# Out:
#                word                                            class division  \
# 0             earth              WORDS EXPRESSING ABSTRACT RELATIONS      N/A
# 1          abeyance              WORDS EXPRESSING ABSTRACT RELATIONS      N/A
# 2            object              WORDS EXPRESSING ABSTRACT RELATIONS      N/A
# 3         principle              WORDS EXPRESSING ABSTRACT RELATIONS      N/A
# 4          inhesion              WORDS EXPRESSING ABSTRACT RELATIONS      N/A
# ...             ...                                              ...      ...
# 44124  resurrection  WORDS RELATING TO THE SENTIENT AND MORAL POWERS      N/A
# 44125          nine  WORDS RELATING TO THE SENTIENT AND MORAL POWERS      N/A
# 44126         bible  WORDS RELATING TO THE SENTIENT AND MORAL POWERS      N/A
# 44127     testament  WORDS RELATING TO THE SENTIENT AND MORAL POWERS      N/A
# 44128      guardian  WORDS RELATING TO THE SENTIENT AND MORAL POWERS      N/A
#
#                     section  \
# 0                 EXISTENCE
# 1                 EXISTENCE
# 2                 EXISTENCE
# 3                 EXISTENCE
# 4                 EXISTENCE
# ...                     ...
# 44124  RELIGIOUS AFFECTIONS
# 44125  RELIGIOUS AFFECTIONS
# 44126  RELIGIOUS AFFECTIONS
# 44127  RELIGIOUS AFFECTIONS
# 44128  RELIGIOUS AFFECTIONS
#
#                                     embedding_clustering  \
# 0      [0.04272461, 0.033111572, -0.021224976, -0.031...
# 1      [0.01852417, 0.039001465, -0.02949524, -0.0682...
# 2      [-0.015281677, 0.0048713684, -0.0038871765, -0...
# 3      [0.039489746, 0.047302246, -0.011039734, -0.05...
# 4      [0.01637268, -0.032806396, -0.025100708, -0.04...
# ...                                                  ...
# 44124  [0.012008667, 0.018371582, -0.018218994, -0.03...
# 44125  [0.038970947, 0.0703125, -0.021026611, -0.0572...
# 44126  [-0.00028800964, 0.022644043, -0.019973755, -0...
# 44127  [0.021850586, -0.025665283, -0.018066406, -0.0...
# 44128  [0.013771057, 0.011100769, -0.021774292, -0.00...
#
#                                 embedding_classification
# 0      [0.024032593, 0.022918701, -0.024398804, -0.06...
# 1      [0.005935669, 0.02468872, -0.03262329, -0.0731...
# 2      [-0.03942871, -0.018493652, 0.0003092289, -0.0...
# 3      [0.021484375, 0.016967773, -0.009857178, -0.06...
# 4      [0.015586853, -0.045928955, -0.027908325, -0.0...
# ...                                                  ...
# 44124  [-0.0010471344, -0.0064468384, -0.022781372, -...
# 44125  [0.014175415, 0.049072266, -0.019195557, -0.09...
# 44126  [-0.024993896, -0.0103302, -0.01550293, -0.072...
# 44127  [-0.0036010742, -0.045654297, -0.019226074, -0...
# 44128  [-0.0033950806, -0.0070495605, -0.026290894, -...
#
# [44129 rows x 6 columns]

# %% [markdown]
# Now, in order to efficiently store the class, division, and section of each word, we will prepare a dictionary with the word as the key and the class, division, and section as the values.

# %%
# Create a dictionary where each word maps to its corresponding class, division, and section
words_dict = categories_df.groupby('word').agg('first').to_dict('index')

# Create the metadata list using list comprehension
metadatas = [
    {
        "class": words_dict[word]['class'],
        "division": words_dict[word].get('division', 'N/A'),
        "section": words_dict[word]['section']
    }
    for word in categories_df['word'] if word in words_dict
]

# %% [markdown]
# With the metadata in place, we can now add the embeddings to the vector database using `chromadb` into two different collections, one for clustering and one for classification.

# %%
from tqdm import tqdm
def add_in_batches(collection, documents, embeddings, metadatas, ids, max_batch_size=5461):
    total_items = len(documents)
    for start_idx in tqdm(range(0, total_items, max_batch_size)):
        end_idx = min(start_idx + max_batch_size, total_items)
        batch_documents = documents[start_idx:end_idx]
        batch_embeddings = embeddings[start_idx:end_idx]
        batch_metadatas = metadatas[start_idx:end_idx]
        batch_ids = ids[start_idx:end_idx]
        
        collection.add(
            documents=batch_documents,
            embeddings=batch_embeddings,
            metadatas=batch_metadatas,
            ids=batch_ids
        )

# Assuming categories_df, nomic_embeddings_clustering, nomic_embeddings_classification, and metadatas are already defined
documents = categories_df['word'].tolist()
embeddings_clustering = nomic_embeddings_clustering['embeddings']
embeddings_classification = nomic_embeddings_classification['embeddings']
ids = [f"word_{i}" for i in range(len(documents))]

# Add documents in batches to the clustering collection
add_in_batches(collection_clustering, documents, embeddings_clustering, metadatas, ids)

# Add documents in batches to the classification collection
add_in_batches(collection_classification, documents, embeddings_classification, metadatas, ids)
# Out:
# 100%|██████████| 9/9 [00:27<00:00,  3.04s/it]
# 100%|██████████| 9/9 [00:23<00:00,  2.61s/it]

# %% [markdown]
# ### Now we have successfully stored the embeddings to a vector database using `chromadb` and we can use them for clustering and classification tasks.
